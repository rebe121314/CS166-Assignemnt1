# %%
import numpy as np
import heapq
import matplotlib.pyplot as plt
import scipy.stats as sts
import random




#Code modified from session 2.1 (M/G/1 queue), modified to include manager and more than one queue

class Event:
    '''
    Store the properties of one event in the Schedule class defined below. Each
    event has a time at which it needs to run, a function to call when running
    the event, along with the arguments and keyword arguments to pass to that
    function.
    
    Attributes
    ----------
    timestamp : float
        The time at which the event should run.
    function : callable
        The function to call when running the event.
    args : tuple
        The positional arguments to pass to the function.
    kwargs : dict
        The keyword arguments to pass to the function.

    Methods
    -------
    __lt__(self, other)
        Compare two events based on their timestamp.
    run(self, schedule)
        Run the event by calling the function with the arguments and keyword


    '''
    def __init__(self, timestamp, function, *args, **kwargs):
        self.timestamp = timestamp
        self.function = function
        self.args = args
        self.kwargs = kwargs

    def __lt__(self, other):
        '''
        your docstring
        Parameters
        ----------
        other
            <include your description here>
        
        Returns
        -------
        bool
            <include your description here>
        '''
        return self.timestamp < other.timestamp

    def run(self, schedule):
        '''
        your docstring
        Parameters
        ----------
        schedule
            <include your description here>
        '''
        self.function(schedule, *self.args, **self.kwargs)


class Schedule:
    '''
    Implement an event schedule using a priority queue. You can add events and
    run the next event.
    
    The `now` attribute contains the time at which the last event was run.
    
    Attributes
    ----------
    now : float
        The time at which the last event was run.
    priority_queue : list
        The priority queue of events.

    Methods
    -------
    add_event_at(self, timestamp, function, *args, **kwargs)
        Add an event to the schedule at a specific time.
    add_event_after(self, interval, function, *args, **kwargs)
        Add an event to the schedule after a specific interval.
    next_event_time(self)
        Return the time at which the next event will run.
    run_next_event(self)
        Run the next event in the schedule.
    __repr__(self)
        Return a string representation of the schedule.
    print_events(self)
        Print the schedule and the events in the queue.


    '''
    
    def __init__(self):
        self.now = 0  
        self.priority_queue = []  
    
    def add_event_at(self, timestamp, function, *args, **kwargs):
        '''
        your docstring
        Parameters
        ----------
        <include your list and description here>
        
        Returns
        -------
        <include your list and description here>
        '''
        heapq.heappush(
            self.priority_queue,
            Event(timestamp, function, *args, **kwargs))
    
    def add_event_after(self, interval, function, *args, **kwargs):
        '''
        your docstring
        Parameters
        ----------
        <include your list and description here>
        
        Returns
        -------
        <include your list and description here>
        '''
        self.add_event_at(self.now + interval, function, *args, **kwargs)
    
    def next_event_time(self):
        return self.priority_queue[0].timestamp

    def run_next_event(self):
        '''
        your docstring
        Parameters
        ----------
        <include your list and description here>
        
        Returns
        -------
        <include your list and description here>
        '''
        event = heapq.heappop(self.priority_queue)
        self.now = event.timestamp
        event.run(self)
        
    def __repr__(self):
        return (
            f'Schedule() at time {self.now}min ' +
            f'with {len(self.priority_queue)} events in the queue')
    
    def print_events(self):
        print(repr(self))
        for event in sorted(self.priority_queue):
            print(f'  ⏱ {event.timestamp}min: {event.function.__name__}')

# %%
#create a grocery store simulation using the event and shedule classes

class Costumer:
    '''
    your docstring
    '''
    def __init__(self, id, arrival_time, departure_time):
        self.id = id
        self.arrival_time = arrival_time
        self.departure_time = departure_time

class Queue_MGC:
    def __init__(self, queue_id, service_distribution, manager):
        self.service_distribution = service_distribution
        self.manager = manager
        self.queue_id = queue_id
        self.arrival_times = []
        self.departure_times = []
        self.queue_length = 0
        self.costumers = []
        self.busy = False

    def __lt__(self, other): 
        #compare queues based on queue length
        return self.queue_length < other.queue_length

    def add_costumer(self, schedule, costumer):
        self.queue_length += 1
        self.costumers.append(costumer)
        print(
            f'{schedule.now:5.2f}: Add customer to queue {self.queue_id}  '
            f'Queue length: {self.queue_length}')
        self.arrival_times.append(costumer.arrival_time)
        if self.busy == False:
            schedule.add_event_after(0, self.serve_costumer)
        
    def serve_costumer(self, schedule):
        self.busy = True
        self.queue_length -= 1
        print(
            f'{schedule.now:5.2f}: Start serving customer. '
            f'Queue length: {self.queue_length}')
        service_time = self.service_distribution.rvs()
        schedule.add_event_after(service_time, self.finish_service)
        self.departure_times.append(self.arrival_times[0] + service_time)

    def finish_service(self, schedule):
        manager_probability = random.random()

        if manager_probability < 0.05:
            self.manager.add_costumer(schedule, self.departure_times[-1], self.costumers[-1])

        else:
            self.busy = False
            if self.queue_length > 0:
                schedule.add_event_after(0, self.serve_costumer)

#the manager follows a MG1 queue
class Manager:
    def __init__(self, manager_distribution):
        self.manager_distribution = manager_distribution
        self.arrival_times = []
        self.departure_times = []
        self.costumers = []
        self.queue_length = 0
        self.busy = False

    def add_costumer(self, schedule, arrival_time, costumer):
        self.queue_length += 1
        self.costumers.append(costumer)
        self.arrival_times.append(arrival_time)
        if self.queue_length == 1:
            self.serve_costumer(schedule)
        if self.busy == False:
            schedule.add_event_after(0, self.serve_costumer)

    def serve_costumer(self, schedule):
        self.busy = True
        self.queue_length -= 1
        service_time = self.manager_distribution.rvs()
        schedule.add_event_after(service_time, self.finish_service)
        self.departure_times.append(self.arrival_times[0] + service_time)

    def finish_service(self, schedule):
        self.busy = False
        if self.queue_length > 0:
            schedule.add_event_after(0, self.serve_costumer)

#The class holds the multiple queues, the manager and the costumers
class Grocery_Store:
    def __init__(self, arrival_distribution, service_distribution, manager_distribution, number_queues):
        self.number_queues = number_queues
        self.arrival_distribution = arrival_distribution
        self.service_distribution = service_distribution
        self.manager_distribution = manager_distribution
        self.manager = Manager(self.manager_distribution)
        self.queues = [Queue_MGC(i+1, self.service_distribution, self.manager) for i in range(self.number_queues)]
        self.costumer_number = 0

    def min_length_queue(self):
        #find the queue with the smallest length the ques are classed based on the __lt__ method
        return heapq.nsmallest(1, self.queues)[0]
        
    def add_costumer(self, schedule):
        self.costumer_number += 1
        arrival_time = schedule.now
        costumer = Costumer(self.costumer_number, arrival_time, None)
        min_length_queue = self.min_length_queue()
        min_length_queue.add_costumer(schedule, costumer)
        schedule.add_event_after(self.arrival_distribution.rvs(), self.add_costumer)

    def run(self, shedule):
        shedule.add_event_at(0, self.add_costumer)

def run_simulation(arrival_distribution, service_distribution, manager_distribution, number_queues, simulation_time):
    '''
    your docstring
    Parameters
    ----------
    <include your list and description here>
    
    Returns
    -------
    <include your list and description here>
    '''
    schedule = Schedule()
    grocery_store = Grocery_Store(arrival_distribution, service_distribution, manager_distribution, number_queues)
    grocery_store.run(schedule)
    while schedule.next_event_time() < simulation_time:
        schedule.run_next_event()
    return grocery_store

# %%
arrival_distribution = sts.expon(scale=1)
service_distribution = sts.norm(3, 1)
manager_distribution = sts.norm(5, 2)
number_queues = 5
simulation_time = 500
grocery_store = run_simulation(arrival_distribution=arrival_distribution, service_distribution=service_distribution, manager_distribution=manager_distribution, number_queues=number_queues, simulation_time=simulation_time)
sol = []
for queue in grocery_store.queues:
    sol.append(queue.queue_length)
print(f'🧍🏾‍♀️ There are {sol} people in the queue')
# Out:
#  0.00: Add customer to queue 1  Queue length: 1
#  0.00: Start serving customer. Queue length: 0
#  1.58: Add customer to queue 1  Queue length: 1
#  2.78: Add customer to queue 2  Queue length: 1
#  2.78: Start serving customer. Queue length: 0
#  4.17: Start serving customer. Queue length: 0
#  4.28: Add customer to queue 1  Queue length: 1
#  6.16: Add customer to queue 2  Queue length: 1
#  6.16: Start serving customer. Queue length: 0
#  8.17: Start serving customer. Queue length: 0
#  8.37: Add customer to queue 1  Queue length: 1
#  8.42: Add customer to queue 2  Queue length: 1
#  9.62: Add customer to queue 3  Queue length: 1
#  9.62: Start serving customer. Queue length: 0
# 10.12: Add customer to queue 3  Queue length: 1
# 10.39: Add customer to queue 4  Queue length: 1
# 10.39: Start serving customer. Queue length: 0
# 11.54: Start serving customer. Queue length: 0
# 11.56: Add customer to queue 1  Queue length: 1
# 12.69: Add customer to queue 4  Queue length: 1
# 12.69: Start serving customer. Queue length: 0
# 12.89: Start serving customer. Queue length: 0
# 12.93: Add customer to queue 3  Queue length: 1
# 13.43: Add customer to queue 4  Queue length: 1
# 14.12: Start serving customer. Queue length: 0
# 14.19: Add customer to queue 1  Queue length: 1
# 15.10: Add customer to queue 5  Queue length: 1
# 15.10: Start serving customer. Queue length: 0
# 15.31: Start serving customer. Queue length: 0
# 15.48: Start serving customer. Queue length: 0
# 16.21: Start serving customer. Queue length: 0
# 19.27: Add customer to queue 1  Queue length: 1
# 19.90: Add customer to queue 3  Queue length: 1
# 19.90: Start serving customer. Queue length: 0
# 20.42: Add customer to queue 3  Queue length: 1
# 20.63: Add customer to queue 4  Queue length: 1
# 21.69: Add customer to queue 5  Queue length: 1
# 21.69: Start serving customer. Queue length: 0
# 21.89: Add customer to queue 5  Queue length: 1
# 23.24: Start serving customer. Queue length: 0
# 23.55: Add customer to queue 1  Queue length: 1
# 23.77: Add customer to queue 1  Queue length: 2
# 24.52: Add customer to queue 2  Queue length: 2
# 25.15: Add customer to queue 3  Queue length: 2
# 25.20: Start serving customer. Queue length: 1
# 25.52: Start serving customer. Queue length: 0
# 25.81: Add customer to queue 5  Queue length: 1
# 26.25: Add customer to queue 3  Queue length: 2
# 26.73: Add customer to queue 4  Queue length: 2
# 27.07: Start serving customer. Queue length: 1
# 27.29: Add customer to queue 1  Queue length: 2
# 28.59: Start serving customer. Queue length: 0
# 28.86: Add customer to queue 5  Queue length: 1
# 29.35: Add customer to queue 5  Queue length: 2
# 29.45: Start serving customer. Queue length: 1
# 31.37: Start serving customer. Queue length: 1
# 31.81: Add customer to queue 3  Queue length: 2
# 31.94: Start serving customer. Queue length: 1
# 32.01: Add customer to queue 1  Queue length: 2
# 32.02: Add customer to queue 5  Queue length: 2
# 32.98: Add customer to queue 1  Queue length: 3
# 33.03: Add customer to queue 2  Queue length: 3
# 33.26: Add customer to queue 3  Queue length: 3
# 33.67: Add customer to queue 4  Queue length: 3
# 33.74: Add customer to queue 5  Queue length: 3
# 34.07: Start serving customer. Queue length: 2
# 34.38: Start serving customer. Queue length: 2
# 35.20: Start serving customer. Queue length: 2
# 36.26: Start serving customer. Queue length: 1
# 37.85: Start serving customer. Queue length: 1
# 38.13: Start serving customer. Queue length: 1
# 39.88: Start serving customer. Queue length: 0
# 40.29: Add customer to queue 3  Queue length: 1
# 40.37: Start serving customer. Queue length: 0
# 40.41: Start serving customer. Queue length: 0
# 40.64: Add customer to queue 1  Queue length: 1
# 42.31: Start serving customer. Queue length: 0
# 42.63: Add customer to queue 3  Queue length: 1
# 43.43: Add customer to queue 5  Queue length: 1
# 43.73: Start serving customer. Queue length: 0
# 44.14: Add customer to queue 1  Queue length: 1
# 44.57: Add customer to queue 1  Queue length: 2
# 45.13: Start serving customer. Queue length: 0
# 45.43: Add customer to queue 3  Queue length: 1
# 45.62: Start serving customer. Queue length: 0
# 45.88: Start serving customer. Queue length: 1
# 46.42: Add customer to queue 5  Queue length: 1
# 46.44: Add customer to queue 1  Queue length: 2
# 46.58: Start serving customer. Queue length: 0
# 47.24: Add customer to queue 3  Queue length: 1
# 48.08: Add customer to queue 3  Queue length: 2
# 48.71: Add customer to queue 5  Queue length: 2
# 49.08: Start serving customer. Queue length: 1
# 49.15: Start serving customer. Queue length: 1
# 49.25: Start serving customer. Queue length: 1
# 49.40: Add customer to queue 1  Queue length: 2
# 49.54: Add customer to queue 3  Queue length: 2
# 50.01: Add customer to queue 5  Queue length: 2
# 51.97: Add customer to queue 1  Queue length: 3
# 52.90: Start serving customer. Queue length: 1
# 53.04: Add customer to queue 5  Queue length: 2
# 53.11: Add customer to queue 3  Queue length: 3
# 55.38: Add customer to queue 5  Queue length: 3
# 57.46: Add customer to queue 1  Queue length: 4
# 58.68: Add customer to queue 2  Queue length: 4
# 60.65: Add customer to queue 3  Queue length: 4
# 62.08: Add customer to queue 4  Queue length: 4
# 66.03: Add customer to queue 5  Queue length: 4
# 66.17: Add customer to queue 1  Queue length: 5
# 67.42: Add customer to queue 2  Queue length: 5
# 67.65: Add customer to queue 3  Queue length: 5
# 68.27: Add customer to queue 4  Queue length: 5
# 70.17: Add customer to queue 5  Queue length: 5
# 73.28: Add customer to queue 1  Queue length: 6
# 73.36: Add customer to queue 2  Queue length: 6
# 74.57: Add customer to queue 3  Queue length: 6
# 75.36: Add customer to queue 4  Queue length: 6
# 75.87: Add customer to queue 5  Queue length: 6
# 77.48: Add customer to queue 1  Queue length: 7
# 77.78: Add customer to queue 2  Queue length: 7
# 78.24: Add customer to queue 3  Queue length: 7
# 79.06: Add customer to queue 4  Queue length: 7
# 79.57: Add customer to queue 5  Queue length: 7
# 82.38: Add customer to queue 1  Queue length: 8
# 82.83: Add customer to queue 2  Queue length: 8
# 83.46: Add customer to queue 3  Queue length: 8
# 83.65: Add customer to queue 4  Queue length: 8
# 83.95: Add customer to queue 5  Queue length: 8
# 84.26: Add customer to queue 1  Queue length: 9
# 84.69: Add customer to queue 2  Queue length: 9
# 84.83: Add customer to queue 3  Queue length: 9
# 85.48: Add customer to queue 4  Queue length: 9
# 86.10: Add customer to queue 5  Queue length: 9
# 86.73: Add customer to queue 1  Queue length: 10
# 88.39: Add customer to queue 2  Queue length: 10
# 89.77: Add customer to queue 3  Queue length: 10
# 90.55: Add customer to queue 4  Queue length: 10
# 91.61: Add customer to queue 5  Queue length: 10
# 91.85: Add customer to queue 1  Queue length: 11
# 91.86: Add customer to queue 2  Queue length: 11
# 93.55: Add customer to queue 3  Queue length: 11
# 94.67: Add customer to queue 4  Queue length: 11
# 96.48: Add customer to queue 5  Queue length: 11
# 97.10: Add customer to queue 1  Queue length: 12
# 97.54: Add customer to queue 2  Queue length: 12
# 98.78: Add customer to queue 3  Queue length: 12
# 99.37: Add customer to queue 4  Queue length: 12
# 99.53: Add customer to queue 5  Queue length: 12
# 100.29: Add customer to queue 1  Queue length: 13
# 100.46: Add customer to queue 2  Queue length: 13
# 100.57: Add customer to queue 3  Queue length: 13
# 102.53: Add customer to queue 4  Queue length: 13
# 105.25: Add customer to queue 5  Queue length: 13
# 106.14: Add customer to queue 1  Queue length: 14
# 106.34: Add customer to queue 2  Queue length: 14
# 107.29: Add customer to queue 3  Queue length: 14
# 107.41: Add customer to queue 4  Queue length: 14
# 108.01: Add customer to queue 5  Queue length: 14
# 108.94: Add customer to queue 1  Queue length: 15
# 109.50: Add customer to queue 2  Queue length: 15
# 111.97: Add customer to queue 3  Queue length: 15
# 116.02: Add customer to queue 4  Queue length: 15
# 116.12: Add customer to queue 5  Queue length: 15
# 116.68: Add customer to queue 1  Queue length: 16
# 117.15: Add customer to queue 2  Queue length: 16
# 117.98: Add customer to queue 3  Queue length: 16
# 118.50: Add customer to queue 4  Queue length: 16
# 119.13: Add customer to queue 5  Queue length: 16
# 119.79: Add customer to queue 1  Queue length: 17
# 120.94: Add customer to queue 2  Queue length: 17
# 121.66: Add customer to queue 3  Queue length: 17
# 121.97: Add customer to queue 4  Queue length: 17
# 122.50: Add customer to queue 5  Queue length: 17
# 123.71: Add customer to queue 1  Queue length: 18
# 123.97: Add customer to queue 2  Queue length: 18
# 125.35: Add customer to queue 3  Queue length: 18
# 127.20: Add customer to queue 4  Queue length: 18
# 127.30: Add customer to queue 5  Queue length: 18
# 128.46: Add customer to queue 1  Queue length: 19
# 129.11: Add customer to queue 2  Queue length: 19
# 131.11: Add customer to queue 3  Queue length: 19
# 131.43: Add customer to queue 4  Queue length: 19
# 132.78: Add customer to queue 5  Queue length: 19
# 133.32: Add customer to queue 1  Queue length: 20
# 133.68: Add customer to queue 2  Queue length: 20
# 133.68: Add customer to queue 3  Queue length: 20
# 135.07: Add customer to queue 4  Queue length: 20
# 135.59: Add customer to queue 5  Queue length: 20
# 136.56: Add customer to queue 1  Queue length: 21
# 136.68: Add customer to queue 2  Queue length: 21
# 137.51: Add customer to queue 3  Queue length: 21
# 137.88: Add customer to queue 4  Queue length: 21
# 139.18: Add customer to queue 5  Queue length: 21
# 139.48: Add customer to queue 1  Queue length: 22
# 139.98: Add customer to queue 2  Queue length: 22
# 140.36: Add customer to queue 3  Queue length: 22
# 140.51: Add customer to queue 4  Queue length: 22
# 144.50: Add customer to queue 5  Queue length: 22
# 144.88: Add customer to queue 1  Queue length: 23
# 146.66: Add customer to queue 2  Queue length: 23
# 148.26: Add customer to queue 3  Queue length: 23
# 149.52: Add customer to queue 4  Queue length: 23
# 149.98: Add customer to queue 5  Queue length: 23
# 150.97: Add customer to queue 1  Queue length: 24
# 150.98: Add customer to queue 2  Queue length: 24
# 151.05: Add customer to queue 3  Queue length: 24
# 152.06: Add customer to queue 4  Queue length: 24
# 152.43: Add customer to queue 5  Queue length: 24
# 152.56: Add customer to queue 1  Queue length: 25
# 154.08: Add customer to queue 2  Queue length: 25
# 154.31: Add customer to queue 3  Queue length: 25
# 155.35: Add customer to queue 4  Queue length: 25
# 156.59: Add customer to queue 5  Queue length: 25
# 158.02: Add customer to queue 1  Queue length: 26
# 158.14: Add customer to queue 2  Queue length: 26
# 158.44: Add customer to queue 3  Queue length: 26
# 165.24: Add customer to queue 4  Queue length: 26
# 166.45: Add customer to queue 5  Queue length: 26
# 167.36: Add customer to queue 1  Queue length: 27
# 168.29: Add customer to queue 2  Queue length: 27
# 169.21: Add customer to queue 3  Queue length: 27
# 170.34: Add customer to queue 4  Queue length: 27
# 171.72: Add customer to queue 5  Queue length: 27
# 171.91: Add customer to queue 1  Queue length: 28
# 173.83: Add customer to queue 2  Queue length: 28
# 174.99: Add customer to queue 3  Queue length: 28
# 175.48: Add customer to queue 4  Queue length: 28
# 175.81: Add customer to queue 5  Queue length: 28
# 176.54: Add customer to queue 1  Queue length: 29
# 177.20: Add customer to queue 2  Queue length: 29
# 178.94: Add customer to queue 3  Queue length: 29
# 180.59: Add customer to queue 4  Queue length: 29
# 183.06: Add customer to queue 5  Queue length: 29
# 183.31: Add customer to queue 1  Queue length: 30
# 183.38: Add customer to queue 2  Queue length: 30
# 186.34: Add customer to queue 3  Queue length: 30
# 187.31: Add customer to queue 4  Queue length: 30
# 187.79: Add customer to queue 5  Queue length: 30
# 188.16: Add customer to queue 1  Queue length: 31
# 191.79: Add customer to queue 2  Queue length: 31
# 192.05: Add customer to queue 3  Queue length: 31
# 194.45: Add customer to queue 4  Queue length: 31
# 195.48: Add customer to queue 5  Queue length: 31
# 198.39: Add customer to queue 1  Queue length: 32
# 199.95: Add customer to queue 2  Queue length: 32
# 201.79: Add customer to queue 3  Queue length: 32
# 202.07: Add customer to queue 4  Queue length: 32
# 202.10: Add customer to queue 5  Queue length: 32
# 202.98: Add customer to queue 1  Queue length: 33
# 203.47: Add customer to queue 2  Queue length: 33
# 204.42: Add customer to queue 3  Queue length: 33
# 204.73: Add customer to queue 4  Queue length: 33
# 204.75: Add customer to queue 5  Queue length: 33
# 206.39: Add customer to queue 1  Queue length: 34
# 206.50: Add customer to queue 2  Queue length: 34
# 207.53: Add customer to queue 3  Queue length: 34
# 208.05: Add customer to queue 4  Queue length: 34
# 208.75: Add customer to queue 5  Queue length: 34
# 209.21: Add customer to queue 1  Queue length: 35
# 209.79: Add customer to queue 2  Queue length: 35
# 211.28: Add customer to queue 3  Queue length: 35
# 211.51: Add customer to queue 4  Queue length: 35
# 211.92: Add customer to queue 5  Queue length: 35
# 212.29: Add customer to queue 1  Queue length: 36
# 216.71: Add customer to queue 2  Queue length: 36
# 216.94: Add customer to queue 3  Queue length: 36
# 217.21: Add customer to queue 4  Queue length: 36
# 217.39: Add customer to queue 5  Queue length: 36
# 217.39: Add customer to queue 1  Queue length: 37
# 219.30: Add customer to queue 2  Queue length: 37
# 219.48: Add customer to queue 3  Queue length: 37
# 220.53: Add customer to queue 4  Queue length: 37
# 221.56: Add customer to queue 5  Queue length: 37
# 222.55: Add customer to queue 1  Queue length: 38
# 222.83: Add customer to queue 2  Queue length: 38
# 223.46: Add customer to queue 3  Queue length: 38
# 223.59: Add customer to queue 4  Queue length: 38
# 223.82: Add customer to queue 5  Queue length: 38
# 228.21: Add customer to queue 1  Queue length: 39
# 228.74: Add customer to queue 2  Queue length: 39
# 229.38: Add customer to queue 3  Queue length: 39
# 229.45: Add customer to queue 4  Queue length: 39
# 229.56: Add customer to queue 5  Queue length: 39
# 230.14: Add customer to queue 1  Queue length: 40
# 231.15: Add customer to queue 2  Queue length: 40
# 232.06: Add customer to queue 3  Queue length: 40
# 232.66: Add customer to queue 4  Queue length: 40
# 232.83: Add customer to queue 5  Queue length: 40
# 235.25: Add customer to queue 1  Queue length: 41
# 236.63: Add customer to queue 2  Queue length: 41
# 237.20: Add customer to queue 3  Queue length: 41
# 239.34: Add customer to queue 4  Queue length: 41
# 240.43: Add customer to queue 5  Queue length: 41
# 242.20: Add customer to queue 1  Queue length: 42
# 243.03: Add customer to queue 2  Queue length: 42
# 243.70: Add customer to queue 3  Queue length: 42
# 243.74: Add customer to queue 4  Queue length: 42
# 246.83: Add customer to queue 5  Queue length: 42
# 247.11: Add customer to queue 1  Queue length: 43
# 247.63: Add customer to queue 2  Queue length: 43
# 248.26: Add customer to queue 3  Queue length: 43
# 248.34: Add customer to queue 4  Queue length: 43
# 251.65: Add customer to queue 5  Queue length: 43
# 252.93: Add customer to queue 1  Queue length: 44
# 253.41: Add customer to queue 2  Queue length: 44
# 253.82: Add customer to queue 3  Queue length: 44
# 254.57: Add customer to queue 4  Queue length: 44
# 255.16: Add customer to queue 5  Queue length: 44
# 256.66: Add customer to queue 1  Queue length: 45
# 259.16: Add customer to queue 2  Queue length: 45
# 259.44: Add customer to queue 3  Queue length: 45
# 261.49: Add customer to queue 4  Queue length: 45
# 262.38: Add customer to queue 5  Queue length: 45
# 262.53: Add customer to queue 1  Queue length: 46
# 263.62: Add customer to queue 2  Queue length: 46
# 263.96: Add customer to queue 3  Queue length: 46
# 264.53: Add customer to queue 4  Queue length: 46
# 266.71: Add customer to queue 5  Queue length: 46
# 266.78: Add customer to queue 1  Queue length: 47
# 267.22: Add customer to queue 2  Queue length: 47
# 267.86: Add customer to queue 3  Queue length: 47
# 267.89: Add customer to queue 4  Queue length: 47
# 268.16: Add customer to queue 5  Queue length: 47
# 272.74: Add customer to queue 1  Queue length: 48
# 273.89: Add customer to queue 2  Queue length: 48
# 276.29: Add customer to queue 3  Queue length: 48
# 277.20: Add customer to queue 4  Queue length: 48
# 278.24: Add customer to queue 5  Queue length: 48
# 279.46: Add customer to queue 1  Queue length: 49
# 280.76: Add customer to queue 2  Queue length: 49
# 280.99: Add customer to queue 3  Queue length: 49
# 282.26: Add customer to queue 4  Queue length: 49
# 284.34: Add customer to queue 5  Queue length: 49
# 285.49: Add customer to queue 1  Queue length: 50
# 286.25: Add customer to queue 2  Queue length: 50
# 286.34: Add customer to queue 3  Queue length: 50
# 288.83: Add customer to queue 4  Queue length: 50
# 289.14: Add customer to queue 5  Queue length: 50
# 289.21: Add customer to queue 1  Queue length: 51
# 289.36: Add customer to queue 2  Queue length: 51
# 289.97: Add customer to queue 3  Queue length: 51
# 290.99: Add customer to queue 4  Queue length: 51
# 291.49: Add customer to queue 5  Queue length: 51
# 292.20: Add customer to queue 1  Queue length: 52
# 292.67: Add customer to queue 2  Queue length: 52
# 293.40: Add customer to queue 3  Queue length: 52
# 297.61: Add customer to queue 4  Queue length: 52
# 297.81: Add customer to queue 5  Queue length: 52
# 298.68: Add customer to queue 1  Queue length: 53
# 298.91: Add customer to queue 2  Queue length: 53
# 300.99: Add customer to queue 3  Queue length: 53
# 301.08: Add customer to queue 4  Queue length: 53
# 301.30: Add customer to queue 5  Queue length: 53
# 301.52: Add customer to queue 1  Queue length: 54
# 303.12: Add customer to queue 2  Queue length: 54
# 303.53: Add customer to queue 3  Queue length: 54
# 303.69: Add customer to queue 4  Queue length: 54
# 305.02: Add customer to queue 5  Queue length: 54
# 307.04: Add customer to queue 1  Queue length: 55
# 307.56: Add customer to queue 2  Queue length: 55
# 308.21: Add customer to queue 3  Queue length: 55
# 308.38: Add customer to queue 4  Queue length: 55
# 308.48: Add customer to queue 5  Queue length: 55
# 308.54: Add customer to queue 1  Queue length: 56
# 310.33: Add customer to queue 2  Queue length: 56
# 316.47: Add customer to queue 3  Queue length: 56
# 316.80: Add customer to queue 4  Queue length: 56
# 317.81: Add customer to queue 5  Queue length: 56
# 317.85: Add customer to queue 1  Queue length: 57
# 318.58: Add customer to queue 2  Queue length: 57
# 319.62: Add customer to queue 3  Queue length: 57
# 320.05: Add customer to queue 4  Queue length: 57
# 321.89: Add customer to queue 5  Queue length: 57
# 323.34: Add customer to queue 1  Queue length: 58
# 323.52: Add customer to queue 2  Queue length: 58
# 324.58: Add customer to queue 3  Queue length: 58
# 325.28: Add customer to queue 4  Queue length: 58
# 325.41: Add customer to queue 5  Queue length: 58
# 326.37: Add customer to queue 1  Queue length: 59
# 326.64: Add customer to queue 2  Queue length: 59
# 327.98: Add customer to queue 3  Queue length: 59
# 328.51: Add customer to queue 4  Queue length: 59
# 332.14: Add customer to queue 5  Queue length: 59
# 332.26: Add customer to queue 1  Queue length: 60
# 336.28: Add customer to queue 2  Queue length: 60
# 336.49: Add customer to queue 3  Queue length: 60
# 338.15: Add customer to queue 4  Queue length: 60
# 338.39: Add customer to queue 5  Queue length: 60
# 342.13: Add customer to queue 1  Queue length: 61
# 342.95: Add customer to queue 2  Queue length: 61
# 343.17: Add customer to queue 3  Queue length: 61
# 343.17: Add customer to queue 4  Queue length: 61
# 344.21: Add customer to queue 5  Queue length: 61
# 346.00: Add customer to queue 1  Queue length: 62
# 347.15: Add customer to queue 2  Queue length: 62
# 348.38: Add customer to queue 3  Queue length: 62
# 350.79: Add customer to queue 4  Queue length: 62
# 351.88: Add customer to queue 5  Queue length: 62
# 351.90: Add customer to queue 1  Queue length: 63
# 352.14: Add customer to queue 2  Queue length: 63
# 355.76: Add customer to queue 3  Queue length: 63
# 355.93: Add customer to queue 4  Queue length: 63
# 356.57: Add customer to queue 5  Queue length: 63
# 358.11: Add customer to queue 1  Queue length: 64
# 360.22: Add customer to queue 2  Queue length: 64
# 360.68: Add customer to queue 3  Queue length: 64
# 361.78: Add customer to queue 4  Queue length: 64
# 362.04: Add customer to queue 5  Queue length: 64
# 363.11: Add customer to queue 1  Queue length: 65
# 363.61: Add customer to queue 2  Queue length: 65
# 364.78: Add customer to queue 3  Queue length: 65
# 365.51: Add customer to queue 4  Queue length: 65
# 366.24: Add customer to queue 5  Queue length: 65
# 366.42: Add customer to queue 1  Queue length: 66
# 367.14: Add customer to queue 2  Queue length: 66
# 367.31: Add customer to queue 3  Queue length: 66
# 369.61: Add customer to queue 4  Queue length: 66
# 371.41: Add customer to queue 5  Queue length: 66
# 371.42: Add customer to queue 1  Queue length: 67
# 372.02: Add customer to queue 2  Queue length: 67
# 372.52: Add customer to queue 3  Queue length: 67
# 372.57: Add customer to queue 4  Queue length: 67
# 373.44: Add customer to queue 5  Queue length: 67
# 373.82: Add customer to queue 1  Queue length: 68
# 374.69: Add customer to queue 2  Queue length: 68
# 376.61: Add customer to queue 3  Queue length: 68
# 376.72: Add customer to queue 4  Queue length: 68
# 377.47: Add customer to queue 5  Queue length: 68
# 378.31: Add customer to queue 1  Queue length: 69
# 381.51: Add customer to queue 2  Queue length: 69
# 385.96: Add customer to queue 3  Queue length: 69
# 391.60: Add customer to queue 4  Queue length: 69
# 393.22: Add customer to queue 5  Queue length: 69
# 395.95: Add customer to queue 1  Queue length: 70
# 396.52: Add customer to queue 2  Queue length: 70
# 397.15: Add customer to queue 3  Queue length: 70
# 398.38: Add customer to queue 4  Queue length: 70
# 399.54: Add customer to queue 5  Queue length: 70
# 400.10: Add customer to queue 1  Queue length: 71
# 400.13: Add customer to queue 2  Queue length: 71
# 405.34: Add customer to queue 3  Queue length: 71
# 406.59: Add customer to queue 4  Queue length: 71
# 407.80: Add customer to queue 5  Queue length: 71
# 408.91: Add customer to queue 1  Queue length: 72
# 409.21: Add customer to queue 2  Queue length: 72
# 409.73: Add customer to queue 3  Queue length: 72
# 409.76: Add customer to queue 4  Queue length: 72
# 409.86: Add customer to queue 5  Queue length: 72
# 410.20: Add customer to queue 1  Queue length: 73
# 411.11: Add customer to queue 2  Queue length: 73
# 412.40: Add customer to queue 3  Queue length: 73
# 413.52: Add customer to queue 4  Queue length: 73
# 413.86: Add customer to queue 5  Queue length: 73
# 414.26: Add customer to queue 1  Queue length: 74
# 416.91: Add customer to queue 2  Queue length: 74
# 417.25: Add customer to queue 3  Queue length: 74
# 418.12: Add customer to queue 4  Queue length: 74
# 418.23: Add customer to queue 5  Queue length: 74
# 419.39: Add customer to queue 1  Queue length: 75
# 420.09: Add customer to queue 2  Queue length: 75
# 421.08: Add customer to queue 3  Queue length: 75
# 421.09: Add customer to queue 4  Queue length: 75
# 421.39: Add customer to queue 5  Queue length: 75
# 422.75: Add customer to queue 1  Queue length: 76
# 422.83: Add customer to queue 2  Queue length: 76
# 423.51: Add customer to queue 3  Queue length: 76
# 423.56: Add customer to queue 4  Queue length: 76
# 424.86: Add customer to queue 5  Queue length: 76
# 427.37: Add customer to queue 1  Queue length: 77
# 427.62: Add customer to queue 2  Queue length: 77
# 427.84: Add customer to queue 3  Queue length: 77
# 428.77: Add customer to queue 4  Queue length: 77
# 429.12: Add customer to queue 5  Queue length: 77
# 431.35: Add customer to queue 1  Queue length: 78
# 432.41: Add customer to queue 2  Queue length: 78
# 432.62: Add customer to queue 3  Queue length: 78
# 433.06: Add customer to queue 4  Queue length: 78
# 434.20: Add customer to queue 5  Queue length: 78
# 434.21: Add customer to queue 1  Queue length: 79
# 436.15: Add customer to queue 2  Queue length: 79
# 436.23: Add customer to queue 3  Queue length: 79
# 436.41: Add customer to queue 4  Queue length: 79
# 437.41: Add customer to queue 5  Queue length: 79
# 441.15: Add customer to queue 1  Queue length: 80
# 441.22: Add customer to queue 2  Queue length: 80
# 444.31: Add customer to queue 3  Queue length: 80
# 444.66: Add customer to queue 4  Queue length: 80
# 445.03: Add customer to queue 5  Queue length: 80
# 445.53: Add customer to queue 1  Queue length: 81
# 445.55: Add customer to queue 2  Queue length: 81
# 446.65: Add customer to queue 3  Queue length: 81
# 447.20: Add customer to queue 4  Queue length: 81
# 447.73: Add customer to queue 5  Queue length: 81
# 448.94: Add customer to queue 1  Queue length: 82
# 449.23: Add customer to queue 2  Queue length: 82
# 452.00: Add customer to queue 3  Queue length: 82
# 454.78: Add customer to queue 4  Queue length: 82
# 455.45: Add customer to queue 5  Queue length: 82
# 455.50: Add customer to queue 1  Queue length: 83
# 456.22: Add customer to queue 2  Queue length: 83
# 458.12: Add customer to queue 3  Queue length: 83
# 458.41: Add customer to queue 4  Queue length: 83
# 458.54: Add customer to queue 5  Queue length: 83
# 460.76: Add customer to queue 1  Queue length: 84
# 462.05: Add customer to queue 2  Queue length: 84
# 464.47: Add customer to queue 3  Queue length: 84
# 465.61: Add customer to queue 4  Queue length: 84
# 465.75: Add customer to queue 5  Queue length: 84
# 467.33: Add customer to queue 1  Queue length: 85
# 470.52: Add customer to queue 2  Queue length: 85
# 470.78: Add customer to queue 3  Queue length: 85
# 474.06: Add customer to queue 4  Queue length: 85
# 475.28: Add customer to queue 5  Queue length: 85
# 476.49: Add customer to queue 1  Queue length: 86
# 481.00: Add customer to queue 2  Queue length: 86
# 482.07: Add customer to queue 3  Queue length: 86
# 482.14: Add customer to queue 4  Queue length: 86
# 482.43: Add customer to queue 5  Queue length: 86
# 482.44: Add customer to queue 1  Queue length: 87
# 482.47: Add customer to queue 2  Queue length: 87
# 482.86: Add customer to queue 3  Queue length: 87
# 483.16: Add customer to queue 4  Queue length: 87
# 484.71: Add customer to queue 5  Queue length: 87
# 485.94: Add customer to queue 1  Queue length: 88
# 486.68: Add customer to queue 2  Queue length: 88
# 487.02: Add customer to queue 3  Queue length: 88
# 488.83: Add customer to queue 4  Queue length: 88
# 490.70: Add customer to queue 5  Queue length: 88
# 491.02: Add customer to queue 1  Queue length: 89
# 492.58: Add customer to queue 2  Queue length: 89
# 492.73: Add customer to queue 3  Queue length: 89
# 492.90: Add customer to queue 4  Queue length: 89
# 494.58: Add customer to queue 5  Queue length: 89
# 494.75: Add customer to queue 1  Queue length: 90
# 495.42: Add customer to queue 2  Queue length: 90
# 497.57: Add customer to queue 3  Queue length: 90
# 498.64: Add customer to queue 4  Queue length: 90
# 🧍🏾‍♀️ There are [90, 90, 90, 90, 89] people in the queue
