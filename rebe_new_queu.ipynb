# %%
import numpy as np
import heapq
import matplotlib.pyplot as plt
import scipy.stats as sts
import random




#Code modified from session 2.1 (M/G/1 queue), modified to include manager and more than one queue

class Event:
    '''
    Store the properties of one event in the Schedule class defined below. Each
    event has a time at which it needs to run, a function to call when running
    the event, along with the arguments and keyword arguments to pass to that
    function.
    
    Attributes
    ----------
    timestamp : float
        The time at which the event should run.
    function : callable
        The function to call when running the event.
    args : tuple
        The positional arguments to pass to the function.
    kwargs : dict
        The keyword arguments to pass to the function.

    Methods
    -------
    __lt__(self, other)
        Compare two events based on their timestamp.
    run(self, schedule)
        Run the event by calling the function with the arguments and keyword


    '''
    def __init__(self, timestamp, function, *args, **kwargs):
        self.timestamp = timestamp
        self.function = function
        self.args = args
        self.kwargs = kwargs

    def __lt__(self, other):
        '''
        your docstring
        Parameters
        ----------
        other
            <include your description here>
        
        Returns
        -------
        bool
            <include your description here>
        '''
        return self.timestamp < other.timestamp

    def run(self, schedule):
        '''
        your docstring
        Parameters
        ----------
        schedule
            <include your description here>
        '''
        self.function(schedule, *self.args, **self.kwargs)


class Schedule:
    '''
    Implement an event schedule using a priority queue. You can add events and
    run the next event.
    
    The `now` attribute contains the time at which the last event was run.
    
    Attributes
    ----------
    now : float
        The time at which the last event was run.
    priority_queue : list
        The priority queue of events.

    Methods
    -------
    add_event_at(self, timestamp, function, *args, **kwargs)
        Add an event to the schedule at a specific time.
    add_event_after(self, interval, function, *args, **kwargs)
        Add an event to the schedule after a specific interval.
    next_event_time(self)
        Return the time at which the next event will run.
    run_next_event(self)
        Run the next event in the schedule.
    __repr__(self)
        Return a string representation of the schedule.
    print_events(self)
        Print the schedule and the events in the queue.


    '''
    
    def __init__(self):
        self.now = 0  
        self.priority_queue = []  
    
    def add_event_at(self, timestamp, function, *args, **kwargs):
        '''
        your docstring
        Parameters
        ----------
        <include your list and description here>
        
        Returns
        -------
        <include your list and description here>
        '''
        heapq.heappush(
            self.priority_queue,
            Event(timestamp, function, *args, **kwargs))
    
    def add_event_after(self, interval, function, *args, **kwargs):
        '''
        your docstring
        Parameters
        ----------
        <include your list and description here>
        
        Returns
        -------
        <include your list and description here>
        '''
        self.add_event_at(self.now + interval, function, *args, **kwargs)
    
    def next_event_time(self):
        return self.priority_queue[0].timestamp

    def run_next_event(self):
        '''
        your docstring
        Parameters
        ----------
        <include your list and description here>
        
        Returns
        -------
        <include your list and description here>
        '''
        event = heapq.heappop(self.priority_queue)
        self.now = event.timestamp
        event.run(self)
        
    def __repr__(self):
        return (
            f'Schedule() at time {self.now}min ' +
            f'with {len(self.priority_queue)} events in the queue')
    
    def print_events(self):
        print(repr(self))
        for event in sorted(self.priority_queue):
            print(f'  ⏱ {event.timestamp}min: {event.function.__name__}')

# %%
#create a grocery store simulation using the event and shedule classes

class Costumer:
    '''
    your docstring
    '''
    def __init__(self, id, arrival_time, departure_time):
        self.id = id
        self.arrival_time = arrival_time
        self.departure_time = departure_time

class Queue_MGC:
    def __init__(self, queue_id, service_distribution, manager):
        self.service_distribution = service_distribution
        self.manager = manager
        self.queue_id = queue_id
        self.arrival_times = []
        self.departure_times = []
        self.queue_length = 0
        self.costumers = []
        self.busy = False

    def __lt__(self, other): 
        #compare queues based on queue length
        return self.queue_length < other.queue_length

    def add_costumer(self, schedule, costumer):
        self.queue_length += 1
        self.costumers.append(costumer)
        print(
            f'{schedule.now:5.2f}: Add customer to queue {self.queue_id}  '
            f'Queue length: {self.queue_length}')
        self.arrival_times.append(costumer.arrival_time)
        if self.busy == False:
            schedule.add_event_after(0, self.serve_costumer)
        
    def serve_costumer(self, schedule):
        self.busy = True
        self.queue_length -= 1
        print(
            f'{schedule.now:5.2f}: Start serving customer.{self.queue_id} '
            f'Queue length: {self.queue_length}')
        service_time = self.service_distribution.rvs()
        schedule.add_event_after(service_time, self.finish_service)
        self.departure_times.append(self.arrival_times[0] + service_time)

    def finish_service(self, schedule):
        manager_probability = random.random()

        if manager_probability < 0.05:
            self.manager.add_costumer(schedule, self.departure_times[-1], self.costumers[-1])

        else:
            self.busy = False
            if self.queue_length > 0:
                schedule.add_event_after(0, self.serve_costumer)

#the manager follows a MG1 queue
class Manager:
    def __init__(self, manager_distribution):
        self.manager_distribution = manager_distribution
        self.arrival_times = []
        self.departure_times = []
        self.costumers = []
        self.queue_length = 0
        self.busy = False

    def add_costumer(self, schedule, arrival_time, costumer):
        self.queue_length += 1
        self.costumers.append(costumer)
        self.arrival_times.append(arrival_time)
        if self.queue_length == 1:
            self.serve_costumer(schedule)
        if self.busy == False:
            schedule.add_event_after(0, self.serve_costumer)

    def serve_costumer(self, schedule):
        self.busy = True
        self.queue_length -= 1
        service_time = self.manager_distribution.rvs()
        schedule.add_event_after(service_time, self.finish_service)
        self.departure_times.append(self.arrival_times[0] + service_time)

    def finish_service(self, schedule):
        self.busy = False
        if self.queue_length > 0:
            schedule.add_event_after(0, self.serve_costumer)

#The class holds the multiple queues, the manager and the costumers
class Grocery_Store:
    def __init__(self, arrival_distribution, service_distribution, manager_distribution, number_queues):
        self.number_queues = number_queues
        self.arrival_distribution = arrival_distribution
        self.service_distribution = service_distribution
        self.manager_distribution = manager_distribution
        self.manager = Manager(self.manager_distribution)
        self.queues = [Queue_MGC(i+1, self.service_distribution, self.manager) for i in range(self.number_queues)]
        self.costumer_number = 0

    def min_length_queue(self):
        #find the queue with the smallest length the ques are classed based on the __lt__ method
        return heapq.nsmallest(1, self.queues)[0]
        
    def add_costumer(self, schedule):
        self.costumer_number += 1
        arrival_time = schedule.now
        costumer = Costumer(self.costumer_number, arrival_time, None)
        min_length_queue = self.min_length_queue()
        min_length_queue.add_costumer(schedule, costumer)
        schedule.add_event_after(self.arrival_distribution.rvs(), self.add_costumer)

    def run(self, shedule):
        shedule.add_event_at(0, self.add_costumer)

def run_simulation(arrival_distribution, service_distribution, manager_distribution, number_queues, simulation_time):
    '''
    your docstring
    Parameters
    ----------
    <include your list and description here>
    
    Returns
    -------
    <include your list and description here>
    '''
    schedule = Schedule()
    grocery_store = Grocery_Store(arrival_distribution, service_distribution, manager_distribution, number_queues)
    grocery_store.run(schedule)
    while schedule.next_event_time() < simulation_time:
        schedule.run_next_event()
    return grocery_store

# %%
rho = 1/3

average_wait = rho/(2*3*(1-rho))

print(average_wait)

arrival_distribution = sts.expon(scale=1)
service_distribution = sts.uniform(3)
manager_distribution = sts.norm(5, 2)
number_queues = 2
simulation_time = 660
grocery_store = run_simulation(arrival_distribution=arrival_distribution, service_distribution=service_distribution, manager_distribution=manager_distribution, number_queues=number_queues, simulation_time=simulation_time)
sol = []
for queue in grocery_store.queues:
    sol.append(queue.queue_length)
print(f'🧍🏾‍♀️ There are {sol} people in the queue')
# Out:
# 0.08333333333333333
#  0.00: Add customer to queue 1  Queue length: 1
#  0.00: Start serving customer.1 Queue length: 0
#  0.98: Add customer to queue 1  Queue length: 1
#  1.44: Add customer to queue 2  Queue length: 1
#  1.44: Start serving customer.2 Queue length: 0
#  1.93: Add customer to queue 2  Queue length: 1
#  2.53: Add customer to queue 1  Queue length: 2
#  3.98: Start serving customer.1 Queue length: 1
#  4.87: Add customer to queue 1  Queue length: 2
#  5.24: Start serving customer.2 Queue length: 0
#  5.54: Add customer to queue 2  Queue length: 1
#  7.46: Start serving customer.1 Queue length: 1
#  8.79: Start serving customer.2 Queue length: 0
#  9.75: Add customer to queue 2  Queue length: 1
# 10.65: Add customer to queue 1  Queue length: 2
# 10.68: Start serving customer.1 Queue length: 1
# 11.23: Add customer to queue 1  Queue length: 2
# 11.26: Add customer to queue 2  Queue length: 2
# 12.38: Add customer to queue 1  Queue length: 3
# 12.44: Start serving customer.2 Queue length: 1
# 13.85: Start serving customer.1 Queue length: 2
# 15.69: Start serving customer.2 Queue length: 0
# 16.52: Add customer to queue 2  Queue length: 1
# 17.04: Start serving customer.1 Queue length: 1
# 17.22: Add customer to queue 1  Queue length: 2
# 17.49: Add customer to queue 2  Queue length: 2
# 18.84: Add customer to queue 1  Queue length: 3
# 19.38: Start serving customer.2 Queue length: 1
# 20.53: Add customer to queue 2  Queue length: 2
# 20.89: Start serving customer.1 Queue length: 2
# 21.85: Add customer to queue 1  Queue length: 3
# 22.81: Add customer to queue 2  Queue length: 3
# 22.93: Start serving customer.2 Queue length: 2
# 23.02: Add customer to queue 2  Queue length: 3
# 23.21: Add customer to queue 1  Queue length: 4
# 24.19: Start serving customer.1 Queue length: 3
# 24.52: Add customer to queue 1  Queue length: 4
# 24.97: Add customer to queue 2  Queue length: 4
# 25.63: Add customer to queue 1  Queue length: 5
# 26.61: Start serving customer.2 Queue length: 3
# 27.08: Add customer to queue 2  Queue length: 4
# 27.34: Start serving customer.1 Queue length: 4
# 29.14: Add customer to queue 1  Queue length: 5
# 29.61: Add customer to queue 2  Queue length: 5
# 29.80: Start serving customer.2 Queue length: 4
# 29.93: Add customer to queue 2  Queue length: 5
# 30.49: Start serving customer.1 Queue length: 4
# 32.55: Add customer to queue 1  Queue length: 5
# 33.60: Add customer to queue 1  Queue length: 6
# 33.75: Start serving customer.2 Queue length: 4
# 33.87: Add customer to queue 2  Queue length: 5
# 34.34: Start serving customer.1 Queue length: 5
# 34.70: Add customer to queue 1  Queue length: 6
# 35.56: Add customer to queue 2  Queue length: 6
# 37.26: Start serving customer.2 Queue length: 5
# 37.88: Start serving customer.1 Queue length: 5
# 38.06: Add customer to queue 1  Queue length: 6
# 38.92: Add customer to queue 2  Queue length: 6
# 39.93: Add customer to queue 1  Queue length: 7
# 40.72: Start serving customer.2 Queue length: 5
# 41.73: Start serving customer.1 Queue length: 6
# 43.75: Add customer to queue 2  Queue length: 6
# 43.84: Start serving customer.2 Queue length: 5
# 44.09: Add customer to queue 2  Queue length: 6
# 44.87: Start serving customer.1 Queue length: 5
# 45.03: Add customer to queue 1  Queue length: 6
# 45.17: Add customer to queue 1  Queue length: 7
# 46.95: Add customer to queue 2  Queue length: 7
# 47.42: Start serving customer.2 Queue length: 6
# 47.52: Add customer to queue 2  Queue length: 7
# 48.19: Start serving customer.1 Queue length: 6
# 48.20: Add customer to queue 1  Queue length: 7
# 48.90: Add customer to queue 1  Queue length: 8
# 50.88: Add customer to queue 2  Queue length: 8
# 51.08: Start serving customer.2 Queue length: 7
# 52.16: Start serving customer.1 Queue length: 7
# 53.50: Add customer to queue 1  Queue length: 8
# 54.51: Start serving customer.2 Queue length: 6
# 55.72: Add customer to queue 2  Queue length: 7
# 55.76: Start serving customer.1 Queue length: 7
# 56.23: Add customer to queue 1  Queue length: 8
# 57.60: Start serving customer.2 Queue length: 6
# 58.33: Add customer to queue 2  Queue length: 7
# 58.37: Add customer to queue 2  Queue length: 8
# 59.13: Start serving customer.1 Queue length: 7
# 59.78: Add customer to queue 1  Queue length: 8
# 61.47: Start serving customer.2 Queue length: 7
# 61.82: Add customer to queue 2  Queue length: 8
# 61.84: Add customer to queue 1  Queue length: 9
# 62.64: Start serving customer.1 Queue length: 8
# 62.68: Add customer to queue 1  Queue length: 9
# 63.29: Add customer to queue 2  Queue length: 9
# 63.47: Add customer to queue 1  Queue length: 10
# 63.87: Add customer to queue 2  Queue length: 10
# 65.17: Add customer to queue 1  Queue length: 11
# 65.65: Start serving customer.1 Queue length: 10
# 68.22: Add customer to queue 1  Queue length: 11
# 68.95: Start serving customer.1 Queue length: 10
# 70.17: Add customer to queue 1  Queue length: 11
# 70.30: Add customer to queue 2  Queue length: 11
# 70.45: Add customer to queue 1  Queue length: 12
# 71.69: Add customer to queue 2  Queue length: 12
# 71.79: Add customer to queue 1  Queue length: 13
# 72.48: Start serving customer.1 Queue length: 12
# 73.47: Add customer to queue 1  Queue length: 13
# 74.06: Add customer to queue 2  Queue length: 13
# 74.32: Add customer to queue 1  Queue length: 14
# 75.88: Add customer to queue 2  Queue length: 14
# 76.12: Start serving customer.1 Queue length: 13
# 77.69: Add customer to queue 1  Queue length: 14
# 77.81: Add customer to queue 1  Queue length: 15
# 78.21: Add customer to queue 2  Queue length: 15
# 78.42: Add customer to queue 1  Queue length: 16
# 78.69: Add customer to queue 2  Queue length: 16
# 79.22: Add customer to queue 1  Queue length: 17
# 79.39: Add customer to queue 2  Queue length: 17
# 79.58: Start serving customer.1 Queue length: 16
# 80.62: Add customer to queue 1  Queue length: 17
# 82.01: Add customer to queue 1  Queue length: 18
# 82.28: Add customer to queue 2  Queue length: 18
# 82.39: Add customer to queue 1  Queue length: 19
# 82.45: Add customer to queue 2  Queue length: 19
# 82.81: Add customer to queue 1  Queue length: 20
# 82.92: Add customer to queue 2  Queue length: 20
# 83.21: Start serving customer.1 Queue length: 19
# 83.62: Add customer to queue 1  Queue length: 20
# 84.15: Add customer to queue 1  Queue length: 21
# 87.07: Start serving customer.1 Queue length: 20
# 87.50: Add customer to queue 1  Queue length: 21
# 87.84: Add customer to queue 2  Queue length: 21
# 88.40: Add customer to queue 1  Queue length: 22
# 89.09: Add customer to queue 2  Queue length: 22
# 90.07: Add customer to queue 1  Queue length: 23
# 90.26: Start serving customer.1 Queue length: 22
# 90.33: Add customer to queue 1  Queue length: 23
# 91.02: Add customer to queue 2  Queue length: 23
# 92.86: Add customer to queue 1  Queue length: 24
# 94.16: Start serving customer.1 Queue length: 23
# 94.67: Add customer to queue 1  Queue length: 24
# 96.69: Add customer to queue 2  Queue length: 24
# 97.87: Add customer to queue 1  Queue length: 25
# 98.13: Start serving customer.1 Queue length: 24
# 98.56: Add customer to queue 1  Queue length: 25
# 98.94: Add customer to queue 2  Queue length: 25
# 99.11: Add customer to queue 1  Queue length: 26
# 99.24: Add customer to queue 2  Queue length: 26
# 100.48: Add customer to queue 1  Queue length: 27
# 100.65: Add customer to queue 2  Queue length: 27
# 100.92: Add customer to queue 1  Queue length: 28
# 101.58: Add customer to queue 2  Queue length: 28
# 101.77: Start serving customer.1 Queue length: 27
# 102.78: Add customer to queue 1  Queue length: 28
# 105.34: Add customer to queue 1  Queue length: 29
# 105.43: Start serving customer.1 Queue length: 28
# 106.10: Add customer to queue 1  Queue length: 29
# 108.51: Start serving customer.1 Queue length: 28
# 108.92: Add customer to queue 1  Queue length: 29
# 111.96: Start serving customer.1 Queue length: 28
# 111.98: Add customer to queue 1  Queue length: 29
# 112.09: Add customer to queue 2  Queue length: 29
# 113.02: Add customer to queue 1  Queue length: 30
# 115.56: Add customer to queue 2  Queue length: 30
# 116.40: Add customer to queue 1  Queue length: 31
# 116.64: Add customer to queue 2  Queue length: 31
# 120.12: Add customer to queue 1  Queue length: 32
# 120.85: Add customer to queue 2  Queue length: 32
# 122.26: Add customer to queue 1  Queue length: 33
# 125.33: Add customer to queue 2  Queue length: 33
# 127.95: Add customer to queue 1  Queue length: 34
# 134.22: Add customer to queue 2  Queue length: 34
# 135.09: Add customer to queue 1  Queue length: 35
# 136.07: Add customer to queue 2  Queue length: 35
# 139.47: Add customer to queue 1  Queue length: 36
# 140.33: Add customer to queue 2  Queue length: 36
# 141.51: Add customer to queue 1  Queue length: 37
# 143.93: Add customer to queue 2  Queue length: 37
# 145.61: Add customer to queue 1  Queue length: 38
# 146.62: Add customer to queue 2  Queue length: 38
# 147.88: Add customer to queue 1  Queue length: 39
# 148.01: Add customer to queue 2  Queue length: 39
# 149.20: Add customer to queue 1  Queue length: 40
# 149.96: Add customer to queue 2  Queue length: 40
# 150.26: Add customer to queue 1  Queue length: 41
# 150.27: Add customer to queue 2  Queue length: 41
# 150.64: Add customer to queue 1  Queue length: 42
# 151.42: Add customer to queue 2  Queue length: 42
# 151.55: Add customer to queue 1  Queue length: 43
# 154.45: Add customer to queue 2  Queue length: 43
# 157.53: Add customer to queue 1  Queue length: 44
# 158.34: Add customer to queue 2  Queue length: 44
# 158.55: Add customer to queue 1  Queue length: 45
# 160.24: Add customer to queue 2  Queue length: 45
# 161.02: Add customer to queue 1  Queue length: 46
# 161.03: Add customer to queue 2  Queue length: 46
# 162.71: Add customer to queue 1  Queue length: 47
# 162.85: Add customer to queue 2  Queue length: 47
# 163.12: Add customer to queue 1  Queue length: 48
# 164.66: Add customer to queue 2  Queue length: 48
# 165.68: Add customer to queue 1  Queue length: 49
# 165.85: Add customer to queue 2  Queue length: 49
# 165.88: Add customer to queue 1  Queue length: 50
# 166.52: Add customer to queue 2  Queue length: 50
# 166.90: Add customer to queue 1  Queue length: 51
# 168.15: Add customer to queue 2  Queue length: 51
# 168.18: Add customer to queue 1  Queue length: 52
# 169.06: Add customer to queue 2  Queue length: 52
# 169.40: Add customer to queue 1  Queue length: 53
# 172.77: Add customer to queue 2  Queue length: 53
# 172.78: Add customer to queue 1  Queue length: 54
# 173.78: Add customer to queue 2  Queue length: 54
# 174.39: Add customer to queue 1  Queue length: 55
# 177.69: Add customer to queue 2  Queue length: 55
# 177.72: Add customer to queue 1  Queue length: 56
# 177.78: Add customer to queue 2  Queue length: 56
# 179.03: Add customer to queue 1  Queue length: 57
# 179.07: Add customer to queue 2  Queue length: 57
# 180.32: Add customer to queue 1  Queue length: 58
# 181.26: Add customer to queue 2  Queue length: 58
# 181.44: Add customer to queue 1  Queue length: 59
# 181.46: Add customer to queue 2  Queue length: 59
# 182.60: Add customer to queue 1  Queue length: 60
# 183.07: Add customer to queue 2  Queue length: 60
# 184.36: Add customer to queue 1  Queue length: 61
# 184.45: Add customer to queue 2  Queue length: 61
# 184.53: Add customer to queue 1  Queue length: 62
# 185.52: Add customer to queue 2  Queue length: 62
# 185.58: Add customer to queue 1  Queue length: 63
# 186.03: Add customer to queue 2  Queue length: 63
# 187.41: Add customer to queue 1  Queue length: 64
# 187.54: Add customer to queue 2  Queue length: 64
# 189.76: Add customer to queue 1  Queue length: 65
# 191.83: Add customer to queue 2  Queue length: 65
# 192.19: Add customer to queue 1  Queue length: 66
# 196.26: Add customer to queue 2  Queue length: 66
# 196.94: Add customer to queue 1  Queue length: 67
# 197.41: Add customer to queue 2  Queue length: 67
# 197.43: Add customer to queue 1  Queue length: 68
# 197.99: Add customer to queue 2  Queue length: 68
# 198.20: Add customer to queue 1  Queue length: 69
# 199.47: Add customer to queue 2  Queue length: 69
# 200.41: Add customer to queue 1  Queue length: 70
# 201.69: Add customer to queue 2  Queue length: 70
# 204.80: Add customer to queue 1  Queue length: 71
# 206.63: Add customer to queue 2  Queue length: 71
# 206.80: Add customer to queue 1  Queue length: 72
# 206.84: Add customer to queue 2  Queue length: 72
# 209.42: Add customer to queue 1  Queue length: 73
# 209.86: Add customer to queue 2  Queue length: 73
# 210.29: Add customer to queue 1  Queue length: 74
# 210.65: Add customer to queue 2  Queue length: 74
# 211.90: Add customer to queue 1  Queue length: 75
# 211.90: Add customer to queue 2  Queue length: 75
# 213.03: Add customer to queue 1  Queue length: 76
# 213.26: Add customer to queue 2  Queue length: 76
# 214.76: Add customer to queue 1  Queue length: 77
# 215.06: Add customer to queue 2  Queue length: 77
# 216.11: Add customer to queue 1  Queue length: 78
# 217.18: Add customer to queue 2  Queue length: 78
# 217.19: Add customer to queue 1  Queue length: 79
# 217.61: Add customer to queue 2  Queue length: 79
# 218.06: Add customer to queue 1  Queue length: 80
# 218.40: Add customer to queue 2  Queue length: 80
# 218.58: Add customer to queue 1  Queue length: 81
# 219.08: Add customer to queue 2  Queue length: 81
# 219.12: Add customer to queue 1  Queue length: 82
# 219.73: Add customer to queue 2  Queue length: 82
# 220.62: Add customer to queue 1  Queue length: 83
# 220.95: Add customer to queue 2  Queue length: 83
# 221.48: Add customer to queue 1  Queue length: 84
# 221.74: Add customer to queue 2  Queue length: 84
# 221.85: Add customer to queue 1  Queue length: 85
# 222.53: Add customer to queue 2  Queue length: 85
# 223.59: Add customer to queue 1  Queue length: 86
# 224.23: Add customer to queue 2  Queue length: 86
# 227.35: Add customer to queue 1  Queue length: 87
# 227.81: Add customer to queue 2  Queue length: 87
# 228.03: Add customer to queue 1  Queue length: 88
# 228.85: Add customer to queue 2  Queue length: 88
# 229.69: Add customer to queue 1  Queue length: 89
# 230.05: Add customer to queue 2  Queue length: 89
# 232.20: Add customer to queue 1  Queue length: 90
# 232.68: Add customer to queue 2  Queue length: 90
# 233.09: Add customer to queue 1  Queue length: 91
# 233.86: Add customer to queue 2  Queue length: 91
# 234.52: Add customer to queue 1  Queue length: 92
# 235.21: Add customer to queue 2  Queue length: 92
# 236.04: Add customer to queue 1  Queue length: 93
# 236.18: Add customer to queue 2  Queue length: 93
# 241.29: Add customer to queue 1  Queue length: 94
# 242.75: Add customer to queue 2  Queue length: 94
# 243.63: Add customer to queue 1  Queue length: 95
# 245.94: Add customer to queue 2  Queue length: 95
# 246.02: Add customer to queue 1  Queue length: 96
# 246.59: Add customer to queue 2  Queue length: 96
# 246.73: Add customer to queue 1  Queue length: 97
# 246.77: Add customer to queue 2  Queue length: 97
# 246.83: Add customer to queue 1  Queue length: 98
# 248.72: Add customer to queue 2  Queue length: 98
# 249.28: Add customer to queue 1  Queue length: 99
# 251.54: Add customer to queue 2  Queue length: 99
# 251.86: Add customer to queue 1  Queue length: 100
# 251.88: Add customer to queue 2  Queue length: 100
# 252.21: Add customer to queue 1  Queue length: 101
# 252.95: Add customer to queue 2  Queue length: 101
# 253.37: Add customer to queue 1  Queue length: 102
# 253.79: Add customer to queue 2  Queue length: 102
# 254.04: Add customer to queue 1  Queue length: 103
# 254.23: Add customer to queue 2  Queue length: 103
# 255.62: Add customer to queue 1  Queue length: 104
# 257.00: Add customer to queue 2  Queue length: 104
# 257.54: Add customer to queue 1  Queue length: 105
# 257.71: Add customer to queue 2  Queue length: 105
# 258.20: Add customer to queue 1  Queue length: 106
# 260.81: Add customer to queue 2  Queue length: 106
# 261.29: Add customer to queue 1  Queue length: 107
# 262.33: Add customer to queue 2  Queue length: 107
# 262.59: Add customer to queue 1  Queue length: 108
# 265.14: Add customer to queue 2  Queue length: 108
# 270.94: Add customer to queue 1  Queue length: 109
# 272.58: Add customer to queue 2  Queue length: 109
# 274.80: Add customer to queue 1  Queue length: 110
# 275.27: Add customer to queue 2  Queue length: 110
# 276.26: Add customer to queue 1  Queue length: 111
# 278.76: Add customer to queue 2  Queue length: 111
# 279.46: Add customer to queue 1  Queue length: 112
# 280.93: Add customer to queue 2  Queue length: 112
# 282.10: Add customer to queue 1  Queue length: 113
# 286.00: Add customer to queue 2  Queue length: 113
# 286.77: Add customer to queue 1  Queue length: 114
# 289.37: Add customer to queue 2  Queue length: 114
# 290.89: Add customer to queue 1  Queue length: 115
# 291.81: Add customer to queue 2  Queue length: 115
# 293.71: Add customer to queue 1  Queue length: 116
# 294.37: Add customer to queue 2  Queue length: 116
# 294.89: Add customer to queue 1  Queue length: 117
# 299.20: Add customer to queue 2  Queue length: 117
# 299.42: Add customer to queue 1  Queue length: 118
# 299.62: Add customer to queue 2  Queue length: 118
# 300.56: Add customer to queue 1  Queue length: 119
# 301.32: Add customer to queue 2  Queue length: 119
# 301.48: Add customer to queue 1  Queue length: 120
# 302.46: Add customer to queue 2  Queue length: 120
# 303.04: Add customer to queue 1  Queue length: 121
# 303.06: Add customer to queue 2  Queue length: 121
# 303.35: Add customer to queue 1  Queue length: 122
# 304.84: Add customer to queue 2  Queue length: 122
# 305.22: Add customer to queue 1  Queue length: 123
# 306.10: Add customer to queue 2  Queue length: 123
# 306.54: Add customer to queue 1  Queue length: 124
# 307.01: Add customer to queue 2  Queue length: 124
# 307.64: Add customer to queue 1  Queue length: 125
# 308.34: Add customer to queue 2  Queue length: 125
# 310.44: Add customer to queue 1  Queue length: 126
# 312.14: Add customer to queue 2  Queue length: 126
# 313.03: Add customer to queue 1  Queue length: 127
# 313.43: Add customer to queue 2  Queue length: 127
# 315.25: Add customer to queue 1  Queue length: 128
# 316.02: Add customer to queue 2  Queue length: 128
# 318.38: Add customer to queue 1  Queue length: 129
# 320.14: Add customer to queue 2  Queue length: 129
# 321.39: Add customer to queue 1  Queue length: 130
# 321.58: Add customer to queue 2  Queue length: 130
# 322.93: Add customer to queue 1  Queue length: 131
# 323.20: Add customer to queue 2  Queue length: 131
# 324.82: Add customer to queue 1  Queue length: 132
# 325.74: Add customer to queue 2  Queue length: 132
# 326.71: Add customer to queue 1  Queue length: 133
# 326.71: Add customer to queue 2  Queue length: 133
# 326.88: Add customer to queue 1  Queue length: 134
# 328.44: Add customer to queue 2  Queue length: 134
# 328.59: Add customer to queue 1  Queue length: 135
# 328.62: Add customer to queue 2  Queue length: 135
# 329.62: Add customer to queue 1  Queue length: 136
# 329.87: Add customer to queue 2  Queue length: 136
# 329.93: Add customer to queue 1  Queue length: 137
# 332.50: Add customer to queue 2  Queue length: 137
# 332.55: Add customer to queue 1  Queue length: 138
# 332.90: Add customer to queue 2  Queue length: 138
# 333.06: Add customer to queue 1  Queue length: 139
# 334.06: Add customer to queue 2  Queue length: 139
# 335.84: Add customer to queue 1  Queue length: 140
# 339.25: Add customer to queue 2  Queue length: 140
# 340.13: Add customer to queue 1  Queue length: 141
# 341.16: Add customer to queue 2  Queue length: 141
# 342.07: Add customer to queue 1  Queue length: 142
# 345.95: Add customer to queue 2  Queue length: 142
# 346.54: Add customer to queue 1  Queue length: 143
# 347.19: Add customer to queue 2  Queue length: 143
# 348.86: Add customer to queue 1  Queue length: 144
# 350.45: Add customer to queue 2  Queue length: 144
# 351.28: Add customer to queue 1  Queue length: 145
# 353.56: Add customer to queue 2  Queue length: 145
# 353.75: Add customer to queue 1  Queue length: 146
# 353.94: Add customer to queue 2  Queue length: 146
# 354.41: Add customer to queue 1  Queue length: 147
# 355.07: Add customer to queue 2  Queue length: 147
# 355.31: Add customer to queue 1  Queue length: 148
# 357.42: Add customer to queue 2  Queue length: 148
# 358.09: Add customer to queue 1  Queue length: 149
# 358.30: Add customer to queue 2  Queue length: 149
# 358.40: Add customer to queue 1  Queue length: 150
# 358.80: Add customer to queue 2  Queue length: 150
# 359.05: Add customer to queue 1  Queue length: 151
# 359.96: Add customer to queue 2  Queue length: 151
# 360.70: Add customer to queue 1  Queue length: 152
# 361.02: Add customer to queue 2  Queue length: 152
# 361.84: Add customer to queue 1  Queue length: 153
# 362.55: Add customer to queue 2  Queue length: 153
# 363.19: Add customer to queue 1  Queue length: 154
# 363.49: Add customer to queue 2  Queue length: 154
# 364.56: Add customer to queue 1  Queue length: 155
# 367.24: Add customer to queue 2  Queue length: 155
# 367.30: Add customer to queue 1  Queue length: 156
# 369.45: Add customer to queue 2  Queue length: 156
# 369.45: Add customer to queue 1  Queue length: 157
# 371.83: Add customer to queue 2  Queue length: 157
# 372.61: Add customer to queue 1  Queue length: 158
# 373.14: Add customer to queue 2  Queue length: 158
# 373.65: Add customer to queue 1  Queue length: 159
# 373.72: Add customer to queue 2  Queue length: 159
# 373.72: Add customer to queue 1  Queue length: 160
# 378.02: Add customer to queue 2  Queue length: 160
# 378.75: Add customer to queue 1  Queue length: 161
# 379.29: Add customer to queue 2  Queue length: 161
# 380.47: Add customer to queue 1  Queue length: 162
# 380.64: Add customer to queue 2  Queue length: 162
# 381.05: Add customer to queue 1  Queue length: 163
# 381.89: Add customer to queue 2  Queue length: 163
# 382.49: Add customer to queue 1  Queue length: 164
# 383.11: Add customer to queue 2  Queue length: 164
# 386.72: Add customer to queue 1  Queue length: 165
# 387.63: Add customer to queue 2  Queue length: 165
# 387.89: Add customer to queue 1  Queue length: 166
# 388.18: Add customer to queue 2  Queue length: 166
# 388.56: Add customer to queue 1  Queue length: 167
# 388.68: Add customer to queue 2  Queue length: 167
# 389.39: Add customer to queue 1  Queue length: 168
# 390.19: Add customer to queue 2  Queue length: 168
# 390.69: Add customer to queue 1  Queue length: 169
# 394.28: Add customer to queue 2  Queue length: 169
# 394.44: Add customer to queue 1  Queue length: 170
# 394.85: Add customer to queue 2  Queue length: 170
# 395.09: Add customer to queue 1  Queue length: 171
# 395.45: Add customer to queue 2  Queue length: 171
# 395.67: Add customer to queue 1  Queue length: 172
# 397.33: Add customer to queue 2  Queue length: 172
# 397.39: Add customer to queue 1  Queue length: 173
# 398.06: Add customer to queue 2  Queue length: 173
# 399.11: Add customer to queue 1  Queue length: 174
# 399.18: Add customer to queue 2  Queue length: 174
# 399.51: Add customer to queue 1  Queue length: 175
# 400.39: Add customer to queue 2  Queue length: 175
# 400.56: Add customer to queue 1  Queue length: 176
# 401.86: Add customer to queue 2  Queue length: 176
# 402.16: Add customer to queue 1  Queue length: 177
# 402.66: Add customer to queue 2  Queue length: 177
# 402.85: Add customer to queue 1  Queue length: 178
# 402.89: Add customer to queue 2  Queue length: 178
# 404.90: Add customer to queue 1  Queue length: 179
# 405.55: Add customer to queue 2  Queue length: 179
# 406.09: Add customer to queue 1  Queue length: 180
# 406.55: Add customer to queue 2  Queue length: 180
# 407.63: Add customer to queue 1  Queue length: 181
# 408.07: Add customer to queue 2  Queue length: 181
# 410.36: Add customer to queue 1  Queue length: 182
# 413.15: Add customer to queue 2  Queue length: 182
# 413.87: Add customer to queue 1  Queue length: 183
# 413.91: Add customer to queue 2  Queue length: 183
# 414.10: Add customer to queue 1  Queue length: 184
# 415.19: Add customer to queue 2  Queue length: 184
# 418.21: Add customer to queue 1  Queue length: 185
# 418.71: Add customer to queue 2  Queue length: 185
# 420.33: Add customer to queue 1  Queue length: 186
# 421.43: Add customer to queue 2  Queue length: 186
# 421.76: Add customer to queue 1  Queue length: 187
# 422.42: Add customer to queue 2  Queue length: 187
# 422.83: Add customer to queue 1  Queue length: 188
# 422.87: Add customer to queue 2  Queue length: 188
# 423.00: Add customer to queue 1  Queue length: 189
# 425.02: Add customer to queue 2  Queue length: 189
# 426.89: Add customer to queue 1  Queue length: 190
# 427.92: Add customer to queue 2  Queue length: 190
# 428.29: Add customer to queue 1  Queue length: 191
# 429.04: Add customer to queue 2  Queue length: 191
# 430.65: Add customer to queue 1  Queue length: 192
# 430.95: Add customer to queue 2  Queue length: 192
# 431.91: Add customer to queue 1  Queue length: 193
# 432.31: Add customer to queue 2  Queue length: 193
# 432.62: Add customer to queue 1  Queue length: 194
# 432.84: Add customer to queue 2  Queue length: 194
# 436.22: Add customer to queue 1  Queue length: 195
# 439.14: Add customer to queue 2  Queue length: 195
# 439.88: Add customer to queue 1  Queue length: 196
# 440.32: Add customer to queue 2  Queue length: 196
# 440.49: Add customer to queue 1  Queue length: 197
# 441.63: Add customer to queue 2  Queue length: 197
# 441.72: Add customer to queue 1  Queue length: 198
# 443.98: Add customer to queue 2  Queue length: 198
# 444.81: Add customer to queue 1  Queue length: 199
# 445.18: Add customer to queue 2  Queue length: 199
# 445.71: Add customer to queue 1  Queue length: 200
# 446.00: Add customer to queue 2  Queue length: 200
# 447.74: Add customer to queue 1  Queue length: 201
# 448.37: Add customer to queue 2  Queue length: 201
# 450.56: Add customer to queue 1  Queue length: 202
# 450.99: Add customer to queue 2  Queue length: 202
# 451.67: Add customer to queue 1  Queue length: 203
# 452.15: Add customer to queue 2  Queue length: 203
# 455.53: Add customer to queue 1  Queue length: 204
# 456.16: Add customer to queue 2  Queue length: 204
# 456.44: Add customer to queue 1  Queue length: 205
# 457.93: Add customer to queue 2  Queue length: 205
# 462.98: Add customer to queue 1  Queue length: 206
# 464.81: Add customer to queue 2  Queue length: 206
# 466.26: Add customer to queue 1  Queue length: 207
# 466.27: Add customer to queue 2  Queue length: 207
# 466.54: Add customer to queue 1  Queue length: 208
# 466.77: Add customer to queue 2  Queue length: 208
# 467.30: Add customer to queue 1  Queue length: 209
# 467.90: Add customer to queue 2  Queue length: 209
# 469.26: Add customer to queue 1  Queue length: 210
# 470.64: Add customer to queue 2  Queue length: 210
# 474.29: Add customer to queue 1  Queue length: 211
# 475.13: Add customer to queue 2  Queue length: 211
# 475.39: Add customer to queue 1  Queue length: 212
# 476.43: Add customer to queue 2  Queue length: 212
# 477.02: Add customer to queue 1  Queue length: 213
# 477.03: Add customer to queue 2  Queue length: 213
# 477.38: Add customer to queue 1  Queue length: 214
# 477.72: Add customer to queue 2  Queue length: 214
# 478.52: Add customer to queue 1  Queue length: 215
# 479.05: Add customer to queue 2  Queue length: 215
# 479.32: Add customer to queue 1  Queue length: 216
# 480.54: Add customer to queue 2  Queue length: 216
# 480.94: Add customer to queue 1  Queue length: 217
# 481.57: Add customer to queue 2  Queue length: 217
# 481.64: Add customer to queue 1  Queue length: 218
# 481.98: Add customer to queue 2  Queue length: 218
# 482.11: Add customer to queue 1  Queue length: 219
# 482.36: Add customer to queue 2  Queue length: 219
# 482.68: Add customer to queue 1  Queue length: 220
# 483.98: Add customer to queue 2  Queue length: 220
# 487.53: Add customer to queue 1  Queue length: 221
# 487.70: Add customer to queue 2  Queue length: 221
# 487.75: Add customer to queue 1  Queue length: 222
# 489.41: Add customer to queue 2  Queue length: 222
# 492.08: Add customer to queue 1  Queue length: 223
# 493.76: Add customer to queue 2  Queue length: 223
# 494.13: Add customer to queue 1  Queue length: 224
# 494.22: Add customer to queue 2  Queue length: 224
# 495.78: Add customer to queue 1  Queue length: 225
# 499.77: Add customer to queue 2  Queue length: 225
# 500.77: Add customer to queue 1  Queue length: 226
# 501.75: Add customer to queue 2  Queue length: 226
# 502.00: Add customer to queue 1  Queue length: 227
# 502.25: Add customer to queue 2  Queue length: 227
# 503.41: Add customer to queue 1  Queue length: 228
# 503.99: Add customer to queue 2  Queue length: 228
# 504.78: Add customer to queue 1  Queue length: 229
# 504.96: Add customer to queue 2  Queue length: 229
# 505.93: Add customer to queue 1  Queue length: 230
# 506.79: Add customer to queue 2  Queue length: 230
# 507.57: Add customer to queue 1  Queue length: 231
# 508.80: Add customer to queue 2  Queue length: 231
# 509.73: Add customer to queue 1  Queue length: 232
# 510.73: Add customer to queue 2  Queue length: 232
# 511.05: Add customer to queue 1  Queue length: 233
# 511.16: Add customer to queue 2  Queue length: 233
# 511.67: Add customer to queue 1  Queue length: 234
# 511.68: Add customer to queue 2  Queue length: 234
# 512.64: Add customer to queue 1  Queue length: 235
# 512.85: Add customer to queue 2  Queue length: 235
# 513.58: Add customer to queue 1  Queue length: 236
# 514.82: Add customer to queue 2  Queue length: 236
# 516.96: Add customer to queue 1  Queue length: 237
# 519.37: Add customer to queue 2  Queue length: 237
# 520.24: Add customer to queue 1  Queue length: 238
# 520.79: Add customer to queue 2  Queue length: 238
# 520.94: Add customer to queue 1  Queue length: 239
# 522.71: Add customer to queue 2  Queue length: 239
# 522.99: Add customer to queue 1  Queue length: 240
# 523.16: Add customer to queue 2  Queue length: 240
# 523.42: Add customer to queue 1  Queue length: 241
# 526.34: Add customer to queue 2  Queue length: 241
# 530.55: Add customer to queue 1  Queue length: 242
# 532.44: Add customer to queue 2  Queue length: 242
# 533.41: Add customer to queue 1  Queue length: 243
# 534.26: Add customer to queue 2  Queue length: 243
# 534.71: Add customer to queue 1  Queue length: 244
# 535.04: Add customer to queue 2  Queue length: 244
# 535.46: Add customer to queue 1  Queue length: 245
# 535.90: Add customer to queue 2  Queue length: 245
# 539.53: Add customer to queue 1  Queue length: 246
# 539.61: Add customer to queue 2  Queue length: 246
# 541.10: Add customer to queue 1  Queue length: 247
# 542.20: Add customer to queue 2  Queue length: 247
# 545.96: Add customer to queue 1  Queue length: 248
# 546.77: Add customer to queue 2  Queue length: 248
# 548.24: Add customer to queue 1  Queue length: 249
# 550.13: Add customer to queue 2  Queue length: 249
# 550.13: Add customer to queue 1  Queue length: 250
# 552.75: Add customer to queue 2  Queue length: 250
# 554.46: Add customer to queue 1  Queue length: 251
# 555.22: Add customer to queue 2  Queue length: 251
# 555.61: Add customer to queue 1  Queue length: 252
# 555.88: Add customer to queue 2  Queue length: 252
# 555.98: Add customer to queue 1  Queue length: 253
# 556.53: Add customer to queue 2  Queue length: 253
# 557.12: Add customer to queue 1  Queue length: 254
# 557.73: Add customer to queue 2  Queue length: 254
# 558.10: Add customer to queue 1  Queue length: 255
# 558.37: Add customer to queue 2  Queue length: 255
# 558.59: Add customer to queue 1  Queue length: 256
# 558.72: Add customer to queue 2  Queue length: 256
# 558.84: Add customer to queue 1  Queue length: 257
# 559.47: Add customer to queue 2  Queue length: 257
# 559.64: Add customer to queue 1  Queue length: 258
# 560.09: Add customer to queue 2  Queue length: 258
# 562.67: Add customer to queue 1  Queue length: 259
# 563.90: Add customer to queue 2  Queue length: 259
# 564.07: Add customer to queue 1  Queue length: 260
# 564.97: Add customer to queue 2  Queue length: 260
# 565.17: Add customer to queue 1  Queue length: 261
# 565.36: Add customer to queue 2  Queue length: 261
# 566.81: Add customer to queue 1  Queue length: 262
# 567.91: Add customer to queue 2  Queue length: 262
# 569.37: Add customer to queue 1  Queue length: 263
# 570.10: Add customer to queue 2  Queue length: 263
# 570.27: Add customer to queue 1  Queue length: 264
# 570.94: Add customer to queue 2  Queue length: 264
# 571.53: Add customer to queue 1  Queue length: 265
# 575.03: Add customer to queue 2  Queue length: 265
# 575.49: Add customer to queue 1  Queue length: 266
# 575.87: Add customer to queue 2  Queue length: 266
# 577.39: Add customer to queue 1  Queue length: 267
# 578.26: Add customer to queue 2  Queue length: 267
# 579.88: Add customer to queue 1  Queue length: 268
# 580.60: Add customer to queue 2  Queue length: 268
# 581.16: Add customer to queue 1  Queue length: 269
# 583.36: Add customer to queue 2  Queue length: 269
# 583.71: Add customer to queue 1  Queue length: 270
# 584.40: Add customer to queue 2  Queue length: 270
# 585.19: Add customer to queue 1  Queue length: 271
# 586.83: Add customer to queue 2  Queue length: 271
# 587.31: Add customer to queue 1  Queue length: 272
# 587.45: Add customer to queue 2  Queue length: 272
# 587.52: Add customer to queue 1  Queue length: 273
# 587.67: Add customer to queue 2  Queue length: 273
# 590.82: Add customer to queue 1  Queue length: 274
# 590.88: Add customer to queue 2  Queue length: 274
# 591.00: Add customer to queue 1  Queue length: 275
# 591.26: Add customer to queue 2  Queue length: 275
# 591.30: Add customer to queue 1  Queue length: 276
# 591.58: Add customer to queue 2  Queue length: 276
# 592.36: Add customer to queue 1  Queue length: 277
# 593.83: Add customer to queue 2  Queue length: 277
# 595.69: Add customer to queue 1  Queue length: 278
# 597.87: Add customer to queue 2  Queue length: 278
# 598.26: Add customer to queue 1  Queue length: 279
# 599.08: Add customer to queue 2  Queue length: 279
# 600.95: Add customer to queue 1  Queue length: 280
# 603.63: Add customer to queue 2  Queue length: 280
# 604.20: Add customer to queue 1  Queue length: 281
# 605.18: Add customer to queue 2  Queue length: 281
# 605.60: Add customer to queue 1  Queue length: 282
# 605.90: Add customer to queue 2  Queue length: 282
# 608.83: Add customer to queue 1  Queue length: 283
# 608.94: Add customer to queue 2  Queue length: 283
# 609.84: Add customer to queue 1  Queue length: 284
# 610.37: Add customer to queue 2  Queue length: 284
# 610.45: Add customer to queue 1  Queue length: 285
# 613.79: Add customer to queue 2  Queue length: 285
# 614.43: Add customer to queue 1  Queue length: 286
# 614.69: Add customer to queue 2  Queue length: 286
# 615.81: Add customer to queue 1  Queue length: 287
# 615.83: Add customer to queue 2  Queue length: 287
# 618.18: Add customer to queue 1  Queue length: 288
# 620.49: Add customer to queue 2  Queue length: 288
# 620.77: Add customer to queue 1  Queue length: 289
# 622.53: Add customer to queue 2  Queue length: 289
# 625.23: Add customer to queue 1  Queue length: 290
# 626.17: Add customer to queue 2  Queue length: 290
# 627.88: Add customer to queue 1  Queue length: 291
# 630.37: Add customer to queue 2  Queue length: 291
# 631.33: Add customer to queue 1  Queue length: 292
# 631.55: Add customer to queue 2  Queue length: 292
# 632.92: Add customer to queue 1  Queue length: 293
# 634.47: Add customer to queue 2  Queue length: 293
# 636.09: Add customer to queue 1  Queue length: 294
# 636.16: Add customer to queue 2  Queue length: 294
# 636.64: Add customer to queue 1  Queue length: 295
# 638.33: Add customer to queue 2  Queue length: 295
# 640.24: Add customer to queue 1  Queue length: 296
# 641.02: Add customer to queue 2  Queue length: 296
# 641.18: Add customer to queue 1  Queue length: 297
# 641.83: Add customer to queue 2  Queue length: 297
# 643.03: Add customer to queue 1  Queue length: 298
# 643.75: Add customer to queue 2  Queue length: 298
# 643.84: Add customer to queue 1  Queue length: 299
# 644.00: Add customer to queue 2  Queue length: 299
# 644.03: Add customer to queue 1  Queue length: 300
# 644.14: Add customer to queue 2  Queue length: 300
# 644.99: Add customer to queue 1  Queue length: 301
# 646.34: Add customer to queue 2  Queue length: 301
# 646.97: Add customer to queue 1  Queue length: 302
# 648.64: Add customer to queue 2  Queue length: 302
# 649.71: Add customer to queue 1  Queue length: 303
# 649.98: Add customer to queue 2  Queue length: 303
# 651.22: Add customer to queue 1  Queue length: 304
# 652.22: Add customer to queue 2  Queue length: 304
# 652.86: Add customer to queue 1  Queue length: 305
# 653.24: Add customer to queue 2  Queue length: 305
# 654.70: Add customer to queue 1  Queue length: 306
# 654.89: Add customer to queue 2  Queue length: 306
# 654.96: Add customer to queue 1  Queue length: 307
# 656.16: Add customer to queue 2  Queue length: 307
# 656.29: Add customer to queue 1  Queue length: 308
# 657.13: Add customer to queue 2  Queue length: 308
# 657.16: Add customer to queue 1  Queue length: 309
# 657.53: Add customer to queue 2  Queue length: 309
# 🧍🏾‍♀️ There are [309, 309] people in the queue

# %%
arrival_distribution = sts.expon(scale=1)
service_distribution = sts.norm(3, 1)
manager_distribution = sts.norm(5, 2)
number_queues = 3
simulation_time = 660
grocery_store = run_simulation(arrival_distribution=arrival_distribution, service_distribution=service_distribution, manager_distribution=manager_distribution, number_queues=number_queues, simulation_time=simulation_time)
sol = []
for queue in grocery_store.queues:
    sol.append(queue.queue_length)
print(f'🧍🏾‍♀️ There are {sol} people in the queue')
# Out:
#  0.00: Add customer to queue 1  Queue length: 1
#  0.00: Start serving customer. Queue length: 0
#  0.55: Add customer to queue 1  Queue length: 1
#  1.43: Start serving customer. Queue length: 0
#  1.44: Add customer to queue 1  Queue length: 1
#  1.83: Add customer to queue 2  Queue length: 1
#  1.83: Start serving customer. Queue length: 0
#  1.99: Add customer to queue 2  Queue length: 1
#  2.58: Add customer to queue 3  Queue length: 1
#  2.58: Start serving customer. Queue length: 0
#  4.09: Start serving customer. Queue length: 0
#  4.79: Add customer to queue 2  Queue length: 1
#  5.60: Add customer to queue 3  Queue length: 1
#  5.60: Start serving customer. Queue length: 0
#  5.62: Add customer to queue 3  Queue length: 1
#  6.22: Add customer to queue 4  Queue length: 1
#  6.22: Start serving customer. Queue length: 0
#  8.13: Add customer to queue 4  Queue length: 1
#  8.13: Start serving customer. Queue length: 0
#  9.31: Start serving customer. Queue length: 0
#  9.32: Add customer to queue 3  Queue length: 1
# 14.20: Add customer to queue 4  Queue length: 1
# 14.20: Start serving customer. Queue length: 0
# 14.58: Add customer to queue 4  Queue length: 1
# 15.60: Start serving customer. Queue length: 0
# 15.91: Add customer to queue 4  Queue length: 1
# 18.32: Add customer to queue 5  Queue length: 1
# 18.32: Start serving customer. Queue length: 0
# 18.42: Add customer to queue 5  Queue length: 1
# 19.12: Start serving customer. Queue length: 0
# 19.75: Add customer to queue 4  Queue length: 1
# 20.03: Add customer to queue 6  Queue length: 1
# 20.03: Start serving customer. Queue length: 0
# 21.16: Add customer to queue 6  Queue length: 1
# 21.28: Add customer to queue 7  Queue length: 1
# 21.28: Start serving customer. Queue length: 0
# 21.41: Start serving customer. Queue length: 0
# 22.05: Start serving customer. Queue length: 0
# 22.28: Add customer to queue 4  Queue length: 1
# 22.53: Add customer to queue 5  Queue length: 1
# 24.10: Start serving customer. Queue length: 0
# 24.26: Add customer to queue 6  Queue length: 1
# 24.72: Start serving customer. Queue length: 0
# 24.76: Add customer to queue 4  Queue length: 1
# 26.25: Start serving customer. Queue length: 0
# 26.43: Add customer to queue 5  Queue length: 1
# 28.10: Start serving customer. Queue length: 0
# 28.56: Start serving customer. Queue length: 0
# 28.98: Start serving customer. Queue length: 0
# 29.63: Add customer to queue 4  Queue length: 1
# 30.30: Start serving customer. Queue length: 0
# 30.76: Add customer to queue 4  Queue length: 1
# 33.18: Add customer to queue 5  Queue length: 1
# 33.18: Start serving customer. Queue length: 0
# 35.24: Start serving customer. Queue length: 0
# 38.87: Add customer to queue 4  Queue length: 1
# 38.87: Start serving customer. Queue length: 0
# 38.97: Add customer to queue 4  Queue length: 1
# 39.20: Add customer to queue 5  Queue length: 1
# 39.20: Start serving customer. Queue length: 0
# 41.46: Add customer to queue 5  Queue length: 1
# 41.46: Start serving customer. Queue length: 0
# 41.90: Add customer to queue 5  Queue length: 1
# 42.05: Add customer to queue 6  Queue length: 1
# 42.05: Start serving customer. Queue length: 0
# 42.16: Add customer to queue 6  Queue length: 1
# 42.62: Add customer to queue 7  Queue length: 1
# 42.62: Start serving customer. Queue length: 0
# 42.99: Add customer to queue 7  Queue length: 1
# 43.74: Start serving customer. Queue length: 0
# 44.02: Add customer to queue 6  Queue length: 1
# 44.65: Start serving customer. Queue length: 0
# 44.97: Add customer to queue 4  Queue length: 1
# 45.18: Add customer to queue 8  Queue length: 1
# 45.18: Start serving customer. Queue length: 0
# 45.73: Start serving customer. Queue length: 0
# 45.78: Start serving customer. Queue length: 0
# 46.59: Start serving customer. Queue length: 0
# 46.67: Start serving customer. Queue length: 0
# 46.70: Add customer to queue 4  Queue length: 1
# 46.77: Add customer to queue 5  Queue length: 1
# 47.61: Add customer to queue 6  Queue length: 1
# 48.34: Add customer to queue 7  Queue length: 1
# 48.44: Start serving customer. Queue length: 0
# 49.17: Add customer to queue 4  Queue length: 1
# 49.34: Start serving customer. Queue length: 0
# 49.46: Add customer to queue 7  Queue length: 1
# 49.74: Start serving customer. Queue length: 0
# 50.21: Add customer to queue 6  Queue length: 1
# 51.48: Start serving customer. Queue length: 0
# 51.72: Add customer to queue 5  Queue length: 1
# 51.98: Add customer to queue 8  Queue length: 1
# 51.98: Start serving customer. Queue length: 0
# 52.22: Start serving customer. Queue length: 0
# 52.51: Add customer to queue 4  Queue length: 1
# 52.70: Add customer to queue 8  Queue length: 1
# 52.92: Add customer to queue 9  Queue length: 1
# 52.92: Start serving customer. Queue length: 0
# 52.96: Start serving customer. Queue length: 0
# 53.16: Start serving customer. Queue length: 0
# 54.16: Start serving customer. Queue length: 0
# 54.99: Add customer to queue 6  Queue length: 1
# 55.08: Start serving customer. Queue length: 0
# 57.20: Start serving customer. Queue length: 0
# 60.55: Add customer to queue 4  Queue length: 1
# 60.55: Start serving customer. Queue length: 0
# 61.18: Add customer to queue 4  Queue length: 1
# 61.87: Add customer to queue 6  Queue length: 1
# 61.87: Start serving customer. Queue length: 0
# 62.14: Start serving customer. Queue length: 0
# 62.52: Add customer to queue 4  Queue length: 1
# 64.95: Add customer to queue 6  Queue length: 1
# 64.95: Start serving customer. Queue length: 0
# 64.96: Start serving customer. Queue length: 0
# 65.03: Add customer to queue 4  Queue length: 1
# 66.29: Add customer to queue 6  Queue length: 1
# 66.35: Start serving customer. Queue length: 0
# 67.43: Add customer to queue 6  Queue length: 1
# 67.72: Start serving customer. Queue length: 0
# 68.72: Start serving customer. Queue length: 0
# 69.19: Add customer to queue 4  Queue length: 1
# 69.79: Add customer to queue 6  Queue length: 1
# 70.53: Start serving customer. Queue length: 0
# 70.56: Add customer to queue 4  Queue length: 1
# 70.97: Add customer to queue 7  Queue length: 1
# 70.97: Start serving customer. Queue length: 0
# 70.99: Start serving customer. Queue length: 0
# 71.18: Add customer to queue 6  Queue length: 1
# 73.65: Start serving customer. Queue length: 0
# 73.69: Add customer to queue 6  Queue length: 1
# 73.89: Start serving customer. Queue length: 0
# 74.16: Add customer to queue 4  Queue length: 1
# 74.59: Add customer to queue 7  Queue length: 1
# 74.89: Start serving customer. Queue length: 0
# 75.35: Start serving customer. Queue length: 0
# 75.54: Add customer to queue 6  Queue length: 1
# 76.45: Add customer to queue 7  Queue length: 1
# 76.63: Add customer to queue 8  Queue length: 1
# 76.63: Start serving customer. Queue length: 0
# 76.93: Add customer to queue 8  Queue length: 1
# 77.03: Start serving customer. Queue length: 0
# 78.14: Start serving customer. Queue length: 0
# 78.59: Add customer to queue 6  Queue length: 1
# 78.60: Start serving customer. Queue length: 0
# 80.73: Start serving customer. Queue length: 0
# 81.18: Start serving customer. Queue length: 0
# 82.72: Add customer to queue 4  Queue length: 1
# 82.72: Start serving customer. Queue length: 0
# 82.84: Add customer to queue 4  Queue length: 1
# 83.09: Add customer to queue 6  Queue length: 1
# 83.84: Add customer to queue 7  Queue length: 1
# 83.84: Start serving customer. Queue length: 0
# 84.91: Add customer to queue 7  Queue length: 1
# 84.91: Start serving customer. Queue length: 0
# 85.01: Start serving customer. Queue length: 0
# 85.87: Add customer to queue 6  Queue length: 1
# 86.40: Start serving customer. Queue length: 0
# 86.70: Add customer to queue 4  Queue length: 1
# 86.95: Start serving customer. Queue length: 0
# 87.39: Add customer to queue 6  Queue length: 1
# 89.35: Add customer to queue 7  Queue length: 1
# 89.35: Start serving customer. Queue length: 0
# 89.44: Start serving customer. Queue length: 0
# 89.59: Start serving customer. Queue length: 0
# 91.75: Add customer to queue 4  Queue length: 1
# 93.28: Add customer to queue 6  Queue length: 1
# 93.28: Start serving customer. Queue length: 0
# 93.88: Add customer to queue 6  Queue length: 1
# 94.22: Add customer to queue 7  Queue length: 1
# 94.59: Add customer to queue 8  Queue length: 1
# 94.59: Start serving customer. Queue length: 0
# 95.67: Add customer to queue 8  Queue length: 1
# 96.05: Start serving customer. Queue length: 0
# 97.70: Start serving customer. Queue length: 0
# 98.33: Add customer to queue 6  Queue length: 1
# 99.12: Add customer to queue 8  Queue length: 1
# 99.33: Start serving customer. Queue length: 0
# 99.69: Start serving customer. Queue length: 0
# 99.94: Add customer to queue 6  Queue length: 1
# 100.29: Add customer to queue 8  Queue length: 1
# 100.72: Start serving customer. Queue length: 0
# 102.34: Add customer to queue 8  Queue length: 1
# 102.34: Start serving customer. Queue length: 0
# 103.64: Add customer to queue 8  Queue length: 1
# 103.69: Add customer to queue 9  Queue length: 1
# 103.69: Start serving customer. Queue length: 0
# 104.43: Add customer to queue 9  Queue length: 1
# 104.43: Start serving customer. Queue length: 0
# 104.49: Add customer to queue 9  Queue length: 1
# 105.81: Start serving customer. Queue length: 0
# 107.49: Add customer to queue 8  Queue length: 1
# 108.04: Start serving customer. Queue length: 0
# 108.55: Add customer to queue 9  Queue length: 1
# 109.28: Start serving customer. Queue length: 0
# 109.90: Start serving customer. Queue length: 0
# 110.28: Add customer to queue 8  Queue length: 1
# 110.43: Add customer to queue 9  Queue length: 1
# 111.86: Start serving customer. Queue length: 0
# 111.91: Add customer to queue 8  Queue length: 1
# 112.77: Add customer to queue 1  Queue length: 2
# 112.81: Start serving customer. Queue length: 0
# 114.93: Add customer to queue 9  Queue length: 1
# 114.93: Start serving customer. Queue length: 0
# 115.74: Start serving customer. Queue length: 0
# 117.13: Add customer to queue 8  Queue length: 1
# 117.18: Add customer to queue 9  Queue length: 1
# 117.27: Start serving customer. Queue length: 0
# 118.09: Add customer to queue 9  Queue length: 1
# 118.16: Start serving customer. Queue length: 0
# 120.02: Start serving customer. Queue length: 0
# 120.74: Add customer to queue 8  Queue length: 1
# 121.41: Start serving customer. Queue length: 0
# 121.49: Add customer to queue 8  Queue length: 1
# 123.61: Add customer to queue 9  Queue length: 1
# 123.61: Start serving customer. Queue length: 0
# 123.71: Add customer to queue 9  Queue length: 1
# 124.73: Start serving customer. Queue length: 0
# 125.06: Add customer to queue 8  Queue length: 1
# 125.32: Add customer to queue 2  Queue length: 2
# 126.12: Start serving customer. Queue length: 0
# 126.83: Add customer to queue 9  Queue length: 1
# 127.05: Start serving customer. Queue length: 0
# 128.51: Add customer to queue 8  Queue length: 1
# 129.25: Add customer to queue 3  Queue length: 2
# 129.59: Add customer to queue 4  Queue length: 2
# 129.76: Start serving customer. Queue length: 0
# 130.80: Start serving customer. Queue length: 0
# 133.19: Add customer to queue 8  Queue length: 1
# 133.19: Start serving customer. Queue length: 0
# 133.91: Add customer to queue 8  Queue length: 1
# 134.01: Add customer to queue 9  Queue length: 1
# 134.31: Start serving customer. Queue length: 0
# 136.23: Add customer to queue 9  Queue length: 1
# 136.61: Add customer to queue 5  Queue length: 2
# 136.70: Start serving customer. Queue length: 0
# 136.83: Add customer to queue 8  Queue length: 1
# 137.54: Start serving customer. Queue length: 0
# 139.19: Add customer to queue 9  Queue length: 1
# 139.28: Add customer to queue 6  Queue length: 2
# 139.85: Start serving customer. Queue length: 0
# 140.00: Start serving customer. Queue length: 0
# 141.48: Add customer to queue 8  Queue length: 1
# 141.54: Add customer to queue 9  Queue length: 1
# 141.99: Add customer to queue 7  Queue length: 2
# 142.50: Start serving customer. Queue length: 0
# 142.74: Add customer to queue 9  Queue length: 1
# 143.26: Start serving customer. Queue length: 0
# 144.44: Start serving customer. Queue length: 0
# 146.46: Add customer to queue 8  Queue length: 1
# 146.54: Start serving customer. Queue length: 0
# 146.63: Add customer to queue 8  Queue length: 1
# 148.32: Start serving customer. Queue length: 0
# 151.16: Add customer to queue 8  Queue length: 1
# 151.60: Start serving customer. Queue length: 0
# 152.80: Add customer to queue 8  Queue length: 1
# 152.80: Start serving customer. Queue length: 0
# 153.27: Add customer to queue 8  Queue length: 1
# 153.81: Add customer to queue 9  Queue length: 1
# 153.81: Start serving customer. Queue length: 0
# 154.63: Add customer to queue 9  Queue length: 1
# 156.72: Start serving customer. Queue length: 0
# 157.08: Start serving customer. Queue length: 0
# 157.25: Add customer to queue 8  Queue length: 1
# 158.35: Add customer to queue 9  Queue length: 1
# 159.13: Start serving customer. Queue length: 0
# 160.17: Add customer to queue 8  Queue length: 1
# 160.77: Add customer to queue 8  Queue length: 2
# 161.04: Add customer to queue 9  Queue length: 2
# 162.25: Start serving customer. Queue length: 1
# 162.44: Add customer to queue 9  Queue length: 2
# 162.55: Add customer to queue 1  Queue length: 3
# 164.52: Add customer to queue 2  Queue length: 3
# 164.62: Add customer to queue 3  Queue length: 3
# 165.59: Start serving customer. Queue length: 1
# 166.80: Add customer to queue 9  Queue length: 2
# 167.04: Add customer to queue 4  Queue length: 3
# 167.79: Add customer to queue 5  Queue length: 3
# 168.92: Start serving customer. Queue length: 1
# 171.16: Add customer to queue 9  Queue length: 2
# 171.38: Start serving customer. Queue length: 1
# 172.44: Start serving customer. Queue length: 0
# 172.47: Add customer to queue 9  Queue length: 1
# 173.74: Add customer to queue 9  Queue length: 2
# 174.29: Add customer to queue 6  Queue length: 3
# 175.12: Add customer to queue 7  Queue length: 3
# 175.57: Start serving customer. Queue length: 1
# 175.58: Add customer to queue 9  Queue length: 2
# 176.31: Add customer to queue 8  Queue length: 3
# 176.67: Add customer to queue 9  Queue length: 3
# 176.80: Add customer to queue 1  Queue length: 4
# 177.85: Start serving customer. Queue length: 2
# 179.04: Add customer to queue 9  Queue length: 3
# 180.04: Start serving customer. Queue length: 2
# 180.99: Add customer to queue 9  Queue length: 3
# 181.00: Start serving customer. Queue length: 2
# 181.04: Add customer to queue 9  Queue length: 3
# 181.06: Add customer to queue 2  Queue length: 4
# 181.17: Add customer to queue 3  Queue length: 4
# 182.29: Add customer to queue 4  Queue length: 4
# 182.33: Add customer to queue 5  Queue length: 4
# 182.67: Add customer to queue 6  Queue length: 4
# 182.71: Add customer to queue 7  Queue length: 4
# 185.08: Add customer to queue 8  Queue length: 4
# 185.43: Start serving customer. Queue length: 2
# 189.25: Start serving customer. Queue length: 1
# 189.90: Add customer to queue 9  Queue length: 2
# 190.22: Add customer to queue 9  Queue length: 3
# 190.28: Add customer to queue 9  Queue length: 4
# 191.25: Add customer to queue 1  Queue length: 5
# 191.59: Start serving customer. Queue length: 3
# 194.63: Add customer to queue 9  Queue length: 4
# 195.16: Start serving customer. Queue length: 3
# 196.67: Start serving customer. Queue length: 2
# 197.81: Start serving customer. Queue length: 1
# 198.13: Add customer to queue 9  Queue length: 2
# 198.36: Add customer to queue 9  Queue length: 3
# 201.88: Add customer to queue 9  Queue length: 4
# 202.45: Start serving customer. Queue length: 3
# 202.86: Add customer to queue 9  Queue length: 4
# 202.89: Add customer to queue 2  Queue length: 5
# 202.94: Add customer to queue 3  Queue length: 5
# 203.25: Add customer to queue 4  Queue length: 5
# 203.73: Start serving customer. Queue length: 3
# 207.24: Add customer to queue 9  Queue length: 4
# 207.55: Add customer to queue 5  Queue length: 5
# 208.33: Add customer to queue 6  Queue length: 5
# 208.93: Start serving customer. Queue length: 3
# 208.94: Add customer to queue 9  Queue length: 4
# 208.99: Add customer to queue 7  Queue length: 5
# 209.58: Add customer to queue 8  Queue length: 5
# 210.29: Add customer to queue 9  Queue length: 5
# 211.21: Add customer to queue 1  Queue length: 6
# 211.56: Add customer to queue 2  Queue length: 6
# 212.45: Start serving customer. Queue length: 4
# 213.09: Add customer to queue 9  Queue length: 5
# 214.48: Add customer to queue 3  Queue length: 6
# 214.48: Add customer to queue 4  Queue length: 6
# 216.37: Add customer to queue 5  Queue length: 6
# 217.07: Start serving customer. Queue length: 4
# 218.70: Start serving customer. Queue length: 3
# 219.65: Add customer to queue 9  Queue length: 4
# 219.86: Add customer to queue 9  Queue length: 5
# 220.19: Add customer to queue 6  Queue length: 6
# 221.25: Add customer to queue 7  Queue length: 6
# 221.48: Add customer to queue 8  Queue length: 6
# 221.96: Start serving customer. Queue length: 4
# 222.28: Add customer to queue 9  Queue length: 5
# 223.22: Add customer to queue 9  Queue length: 6
# 223.84: Add customer to queue 1  Queue length: 7
# 224.42: Add customer to queue 2  Queue length: 7
# 225.16: Add customer to queue 3  Queue length: 7
# 225.41: Start serving customer. Queue length: 5
# 225.81: Add customer to queue 9  Queue length: 6
# 226.32: Add customer to queue 4  Queue length: 7
# 226.44: Add customer to queue 5  Queue length: 7
# 227.00: Add customer to queue 6  Queue length: 7
# 227.14: Add customer to queue 7  Queue length: 7
# 227.18: Add customer to queue 8  Queue length: 7
# 229.75: Start serving customer. Queue length: 5
# 230.46: Add customer to queue 9  Queue length: 6
# 231.18: Add customer to queue 9  Queue length: 7
# 232.19: Add customer to queue 1  Queue length: 8
# 232.60: Start serving customer. Queue length: 6
# 234.94: Start serving customer. Queue length: 5
# 235.09: Add customer to queue 9  Queue length: 6
# 235.59: Add customer to queue 9  Queue length: 7
# 236.21: Add customer to queue 2  Queue length: 8
# 236.56: Add customer to queue 3  Queue length: 8
# 237.34: Add customer to queue 4  Queue length: 8
# 237.47: Start serving customer. Queue length: 6
# 238.08: Add customer to queue 9  Queue length: 7
# 238.16: Add customer to queue 5  Queue length: 8
# 238.18: Add customer to queue 6  Queue length: 8
# 238.63: Add customer to queue 7  Queue length: 8
# 238.79: Add customer to queue 8  Queue length: 8
# 240.31: Add customer to queue 9  Queue length: 8
# 240.43: Start serving customer. Queue length: 7
# 242.11: Add customer to queue 9  Queue length: 8
# 242.57: Add customer to queue 1  Queue length: 9
# 243.62: Add customer to queue 2  Queue length: 9
# 243.72: Add customer to queue 3  Queue length: 9
# 243.96: Add customer to queue 4  Queue length: 9
# 244.10: Start serving customer. Queue length: 7
# 244.33: Add customer to queue 9  Queue length: 8
# 244.38: Add customer to queue 5  Queue length: 9
# 245.43: Add customer to queue 6  Queue length: 9
# 245.86: Add customer to queue 7  Queue length: 9
# 246.27: Start serving customer. Queue length: 7
# 247.52: Add customer to queue 9  Queue length: 8
# 248.36: Start serving customer. Queue length: 7
# 249.71: Add customer to queue 9  Queue length: 8
# 250.88: Add customer to queue 8  Queue length: 9
# 251.47: Add customer to queue 9  Queue length: 9
# 251.95: Add customer to queue 1  Queue length: 10
# 253.31: Add customer to queue 2  Queue length: 10
# 256.08: Add customer to queue 3  Queue length: 10
# 256.34: Add customer to queue 4  Queue length: 10
# 258.07: Add customer to queue 5  Queue length: 10
# 258.66: Add customer to queue 6  Queue length: 10
# 260.18: Add customer to queue 7  Queue length: 10
# 260.73: Add customer to queue 8  Queue length: 10
# 261.48: Add customer to queue 9  Queue length: 10
# 262.23: Add customer to queue 1  Queue length: 11
# 264.16: Add customer to queue 2  Queue length: 11
# 266.30: Add customer to queue 3  Queue length: 11
# 266.36: Add customer to queue 4  Queue length: 11
# 266.55: Add customer to queue 5  Queue length: 11
# 267.30: Add customer to queue 6  Queue length: 11
# 269.62: Add customer to queue 7  Queue length: 11
# 270.36: Add customer to queue 8  Queue length: 11
# 271.55: Add customer to queue 9  Queue length: 11
# 272.86: Add customer to queue 1  Queue length: 12
# 272.91: Add customer to queue 2  Queue length: 12
# 273.45: Add customer to queue 3  Queue length: 12
# 276.09: Add customer to queue 4  Queue length: 12
# 276.63: Add customer to queue 5  Queue length: 12
# 276.74: Add customer to queue 6  Queue length: 12
# 277.02: Add customer to queue 7  Queue length: 12
# 277.76: Add customer to queue 8  Queue length: 12
# 278.90: Add customer to queue 9  Queue length: 12
# 279.98: Add customer to queue 1  Queue length: 13
# 282.02: Add customer to queue 2  Queue length: 13
# 285.00: Add customer to queue 3  Queue length: 13
# 285.47: Add customer to queue 4  Queue length: 13
# 289.18: Add customer to queue 5  Queue length: 13
# 289.41: Add customer to queue 6  Queue length: 13
# 289.53: Add customer to queue 7  Queue length: 13
# 289.55: Add customer to queue 8  Queue length: 13
# 290.54: Add customer to queue 9  Queue length: 13
# 292.06: Add customer to queue 1  Queue length: 14
# 292.22: Add customer to queue 2  Queue length: 14
# 292.39: Add customer to queue 3  Queue length: 14
# 296.63: Add customer to queue 4  Queue length: 14
# 297.06: Add customer to queue 5  Queue length: 14
# 297.30: Add customer to queue 6  Queue length: 14
# 297.73: Add customer to queue 7  Queue length: 14
# 299.27: Add customer to queue 8  Queue length: 14
# 300.19: Add customer to queue 9  Queue length: 14
# 300.25: Add customer to queue 1  Queue length: 15
# 304.86: Add customer to queue 2  Queue length: 15
# 305.08: Add customer to queue 3  Queue length: 15
# 305.19: Add customer to queue 4  Queue length: 15
# 307.03: Add customer to queue 5  Queue length: 15
# 310.12: Add customer to queue 6  Queue length: 15
# 312.26: Add customer to queue 7  Queue length: 15
# 312.67: Add customer to queue 8  Queue length: 15
# 313.34: Add customer to queue 9  Queue length: 15
# 313.38: Add customer to queue 1  Queue length: 16
# 313.50: Add customer to queue 2  Queue length: 16
# 314.00: Add customer to queue 3  Queue length: 16
# 315.63: Add customer to queue 4  Queue length: 16
# 316.36: Add customer to queue 5  Queue length: 16
# 316.75: Add customer to queue 6  Queue length: 16
# 317.55: Add customer to queue 7  Queue length: 16
# 317.62: Add customer to queue 8  Queue length: 16
# 317.99: Add customer to queue 9  Queue length: 16
# 319.09: Add customer to queue 1  Queue length: 17
# 321.54: Add customer to queue 2  Queue length: 17
# 322.08: Add customer to queue 3  Queue length: 17
# 323.34: Add customer to queue 4  Queue length: 17
# 323.70: Add customer to queue 5  Queue length: 17
# 324.42: Add customer to queue 6  Queue length: 17
# 325.43: Add customer to queue 7  Queue length: 17
# 329.93: Add customer to queue 8  Queue length: 17
# 330.51: Add customer to queue 9  Queue length: 17
# 331.29: Add customer to queue 1  Queue length: 18
# 334.37: Add customer to queue 2  Queue length: 18
# 334.44: Add customer to queue 3  Queue length: 18
# 334.91: Add customer to queue 4  Queue length: 18
# 337.70: Add customer to queue 5  Queue length: 18
# 338.24: Add customer to queue 6  Queue length: 18
# 339.67: Add customer to queue 7  Queue length: 18
# 339.77: Add customer to queue 8  Queue length: 18
# 341.13: Add customer to queue 9  Queue length: 18
# 341.48: Add customer to queue 1  Queue length: 19
# 343.17: Add customer to queue 2  Queue length: 19
# 343.58: Add customer to queue 3  Queue length: 19
# 344.43: Add customer to queue 4  Queue length: 19
# 344.52: Add customer to queue 5  Queue length: 19
# 345.96: Add customer to queue 6  Queue length: 19
# 347.69: Add customer to queue 7  Queue length: 19
# 349.36: Add customer to queue 8  Queue length: 19
# 349.61: Add customer to queue 9  Queue length: 19
# 350.59: Add customer to queue 1  Queue length: 20
# 354.15: Add customer to queue 2  Queue length: 20
# 356.16: Add customer to queue 3  Queue length: 20
# 356.89: Add customer to queue 4  Queue length: 20
# 357.18: Add customer to queue 5  Queue length: 20
# 359.09: Add customer to queue 6  Queue length: 20
# 359.21: Add customer to queue 7  Queue length: 20
# 361.16: Add customer to queue 8  Queue length: 20
# 361.82: Add customer to queue 9  Queue length: 20
# 362.01: Add customer to queue 1  Queue length: 21
# 362.85: Add customer to queue 2  Queue length: 21
# 367.82: Add customer to queue 3  Queue length: 21
# 368.17: Add customer to queue 4  Queue length: 21
# 368.33: Add customer to queue 5  Queue length: 21
# 369.22: Add customer to queue 6  Queue length: 21
# 369.49: Add customer to queue 7  Queue length: 21
# 370.71: Add customer to queue 8  Queue length: 21
# 371.44: Add customer to queue 9  Queue length: 21
# 373.86: Add customer to queue 1  Queue length: 22
# 374.18: Add customer to queue 2  Queue length: 22
# 375.03: Add customer to queue 3  Queue length: 22
# 376.05: Add customer to queue 4  Queue length: 22
# 376.84: Add customer to queue 5  Queue length: 22
# 376.88: Add customer to queue 6  Queue length: 22
# 380.78: Add customer to queue 7  Queue length: 22
# 382.74: Add customer to queue 8  Queue length: 22
# 382.80: Add customer to queue 9  Queue length: 22
# 383.80: Add customer to queue 1  Queue length: 23
# 384.10: Add customer to queue 2  Queue length: 23
# 384.36: Add customer to queue 3  Queue length: 23
# 385.52: Add customer to queue 4  Queue length: 23
# 385.81: Add customer to queue 5  Queue length: 23
# 385.86: Add customer to queue 6  Queue length: 23
# 386.36: Add customer to queue 7  Queue length: 23
# 388.55: Add customer to queue 8  Queue length: 23
# 388.56: Add customer to queue 9  Queue length: 23
# 389.24: Add customer to queue 1  Queue length: 24
# 389.91: Add customer to queue 2  Queue length: 24
# 393.90: Add customer to queue 3  Queue length: 24
# 397.77: Add customer to queue 4  Queue length: 24
# 401.39: Add customer to queue 5  Queue length: 24
# 402.82: Add customer to queue 6  Queue length: 24
# 404.34: Add customer to queue 7  Queue length: 24
# 404.57: Add customer to queue 8  Queue length: 24
# 407.30: Add customer to queue 9  Queue length: 24
# 407.79: Add customer to queue 1  Queue length: 25
# 408.24: Add customer to queue 2  Queue length: 25
# 409.17: Add customer to queue 3  Queue length: 25
# 409.19: Add customer to queue 4  Queue length: 25
# 411.16: Add customer to queue 5  Queue length: 25
# 411.71: Add customer to queue 6  Queue length: 25
# 411.99: Add customer to queue 7  Queue length: 25
# 412.14: Add customer to queue 8  Queue length: 25
# 412.25: Add customer to queue 9  Queue length: 25
# 413.31: Add customer to queue 1  Queue length: 26
# 413.43: Add customer to queue 2  Queue length: 26
# 413.56: Add customer to queue 3  Queue length: 26
# 414.97: Add customer to queue 4  Queue length: 26
# 416.31: Add customer to queue 5  Queue length: 26
# 416.35: Add customer to queue 6  Queue length: 26
# 418.62: Add customer to queue 7  Queue length: 26
# 418.69: Add customer to queue 8  Queue length: 26
# 418.76: Add customer to queue 9  Queue length: 26
# 421.66: Add customer to queue 1  Queue length: 27
# 422.33: Add customer to queue 2  Queue length: 27
# 422.55: Add customer to queue 3  Queue length: 27
# 423.32: Add customer to queue 4  Queue length: 27
# 423.88: Add customer to queue 5  Queue length: 27
# 425.57: Add customer to queue 6  Queue length: 27
# 426.36: Add customer to queue 7  Queue length: 27
# 427.36: Add customer to queue 8  Queue length: 27
# 428.56: Add customer to queue 9  Queue length: 27
# 429.64: Add customer to queue 1  Queue length: 28
# 429.73: Add customer to queue 2  Queue length: 28
# 431.25: Add customer to queue 3  Queue length: 28
# 431.63: Add customer to queue 4  Queue length: 28
# 435.10: Add customer to queue 5  Queue length: 28
# 435.25: Add customer to queue 6  Queue length: 28
# 436.22: Add customer to queue 7  Queue length: 28
# 436.34: Add customer to queue 8  Queue length: 28
# 436.78: Add customer to queue 9  Queue length: 28
# 436.97: Add customer to queue 1  Queue length: 29
# 437.19: Add customer to queue 2  Queue length: 29
# 439.30: Add customer to queue 3  Queue length: 29
# 440.84: Add customer to queue 4  Queue length: 29
# 441.71: Add customer to queue 5  Queue length: 29
# 443.44: Add customer to queue 6  Queue length: 29
# 444.34: Add customer to queue 7  Queue length: 29
# 448.44: Add customer to queue 8  Queue length: 29
# 449.94: Add customer to queue 9  Queue length: 29
# 450.91: Add customer to queue 1  Queue length: 30
# 451.06: Add customer to queue 2  Queue length: 30
# 452.29: Add customer to queue 3  Queue length: 30
# 456.69: Add customer to queue 4  Queue length: 30
# 458.72: Add customer to queue 5  Queue length: 30
# 458.89: Add customer to queue 6  Queue length: 30
# 458.95: Add customer to queue 7  Queue length: 30
# 460.01: Add customer to queue 8  Queue length: 30
# 460.02: Add customer to queue 9  Queue length: 30
# 460.10: Add customer to queue 1  Queue length: 31
# 460.44: Add customer to queue 2  Queue length: 31
# 460.66: Add customer to queue 3  Queue length: 31
# 463.80: Add customer to queue 4  Queue length: 31
# 465.88: Add customer to queue 5  Queue length: 31
# 466.23: Add customer to queue 6  Queue length: 31
# 468.30: Add customer to queue 7  Queue length: 31
# 468.63: Add customer to queue 8  Queue length: 31
# 469.10: Add customer to queue 9  Queue length: 31
# 469.12: Add customer to queue 1  Queue length: 32
# 470.44: Add customer to queue 2  Queue length: 32
# 475.85: Add customer to queue 3  Queue length: 32
# 477.82: Add customer to queue 4  Queue length: 32
# 477.87: Add customer to queue 5  Queue length: 32
# 480.69: Add customer to queue 6  Queue length: 32
# 481.89: Add customer to queue 7  Queue length: 32
# 481.99: Add customer to queue 8  Queue length: 32
# 482.48: Add customer to queue 9  Queue length: 32
# 483.70: Add customer to queue 1  Queue length: 33
# 485.37: Add customer to queue 2  Queue length: 33
# 488.52: Add customer to queue 3  Queue length: 33
# 488.59: Add customer to queue 4  Queue length: 33
# 493.82: Add customer to queue 5  Queue length: 33
# 495.69: Add customer to queue 6  Queue length: 33
# 495.94: Add customer to queue 7  Queue length: 33
# 496.25: Add customer to queue 8  Queue length: 33
# 497.28: Add customer to queue 9  Queue length: 33
# 497.33: Add customer to queue 1  Queue length: 34
# 500.29: Add customer to queue 2  Queue length: 34
# 502.63: Add customer to queue 3  Queue length: 34
# 504.00: Add customer to queue 4  Queue length: 34
# 505.41: Add customer to queue 5  Queue length: 34
# 505.77: Add customer to queue 6  Queue length: 34
# 506.77: Add customer to queue 7  Queue length: 34
# 507.87: Add customer to queue 8  Queue length: 34
# 510.66: Add customer to queue 9  Queue length: 34
# 511.44: Add customer to queue 1  Queue length: 35
# 511.52: Add customer to queue 2  Queue length: 35
# 518.15: Add customer to queue 3  Queue length: 35
# 518.69: Add customer to queue 4  Queue length: 35
# 518.94: Add customer to queue 5  Queue length: 35
# 519.61: Add customer to queue 6  Queue length: 35
# 520.90: Add customer to queue 7  Queue length: 35
# 521.73: Add customer to queue 8  Queue length: 35
# 523.22: Add customer to queue 9  Queue length: 35
# 523.50: Add customer to queue 1  Queue length: 36
# 523.58: Add customer to queue 2  Queue length: 36
# 524.53: Add customer to queue 3  Queue length: 36
# 527.52: Add customer to queue 4  Queue length: 36
# 528.19: Add customer to queue 5  Queue length: 36
# 528.29: Add customer to queue 6  Queue length: 36
# 528.33: Add customer to queue 7  Queue length: 36
# 528.68: Add customer to queue 8  Queue length: 36
# 530.16: Add customer to queue 9  Queue length: 36
# 533.37: Add customer to queue 1  Queue length: 37
# 533.94: Add customer to queue 2  Queue length: 37
# 534.49: Add customer to queue 3  Queue length: 37
# 534.83: Add customer to queue 4  Queue length: 37
# 535.96: Add customer to queue 5  Queue length: 37
# 536.73: Add customer to queue 6  Queue length: 37
# 536.75: Add customer to queue 7  Queue length: 37
# 536.79: Add customer to queue 8  Queue length: 37
# 538.04: Add customer to queue 9  Queue length: 37
# 540.98: Add customer to queue 1  Queue length: 38
# 541.10: Add customer to queue 2  Queue length: 38
# 543.71: Add customer to queue 3  Queue length: 38
# 544.10: Add customer to queue 4  Queue length: 38
# 544.36: Add customer to queue 5  Queue length: 38
# 544.42: Add customer to queue 6  Queue length: 38
# 547.02: Add customer to queue 7  Queue length: 38
# 547.13: Add customer to queue 8  Queue length: 38
# 548.45: Add customer to queue 9  Queue length: 38
# 549.16: Add customer to queue 1  Queue length: 39
# 550.25: Add customer to queue 2  Queue length: 39
# 550.64: Add customer to queue 3  Queue length: 39
# 550.64: Add customer to queue 4  Queue length: 39
# 551.10: Add customer to queue 5  Queue length: 39
# 551.78: Add customer to queue 6  Queue length: 39
# 552.85: Add customer to queue 7  Queue length: 39
# 554.08: Add customer to queue 8  Queue length: 39
# 557.98: Add customer to queue 9  Queue length: 39
# 558.21: Add customer to queue 1  Queue length: 40
# 559.11: Add customer to queue 2  Queue length: 40
# 559.95: Add customer to queue 3  Queue length: 40
# 561.90: Add customer to queue 4  Queue length: 40
# 562.71: Add customer to queue 5  Queue length: 40
# 563.65: Add customer to queue 6  Queue length: 40
# 564.03: Add customer to queue 7  Queue length: 40
# 564.69: Add customer to queue 8  Queue length: 40
# 567.48: Add customer to queue 9  Queue length: 40
# 567.83: Add customer to queue 1  Queue length: 41
# 568.96: Add customer to queue 2  Queue length: 41
# 570.34: Add customer to queue 3  Queue length: 41
# 575.09: Add customer to queue 4  Queue length: 41
# 576.08: Add customer to queue 5  Queue length: 41
# 579.29: Add customer to queue 6  Queue length: 41
# 580.64: Add customer to queue 7  Queue length: 41
# 581.68: Add customer to queue 8  Queue length: 41
# 582.22: Add customer to queue 9  Queue length: 41
# 585.04: Add customer to queue 1  Queue length: 42
# 585.16: Add customer to queue 2  Queue length: 42
# 586.05: Add customer to queue 3  Queue length: 42
# 587.83: Add customer to queue 4  Queue length: 42
# 590.32: Add customer to queue 5  Queue length: 42
# 590.46: Add customer to queue 6  Queue length: 42
# 590.58: Add customer to queue 7  Queue length: 42
# 590.59: Add customer to queue 8  Queue length: 42
# 592.22: Add customer to queue 9  Queue length: 42
# 597.55: Add customer to queue 1  Queue length: 43
# 600.17: Add customer to queue 2  Queue length: 43
# 600.33: Add customer to queue 3  Queue length: 43
# 602.48: Add customer to queue 4  Queue length: 43
# 604.30: Add customer to queue 5  Queue length: 43
# 604.99: Add customer to queue 6  Queue length: 43
# 605.34: Add customer to queue 7  Queue length: 43
# 605.68: Add customer to queue 8  Queue length: 43
# 606.35: Add customer to queue 9  Queue length: 43
# 606.92: Add customer to queue 1  Queue length: 44
# 607.68: Add customer to queue 2  Queue length: 44
# 609.05: Add customer to queue 3  Queue length: 44
# 609.17: Add customer to queue 4  Queue length: 44
# 610.89: Add customer to queue 5  Queue length: 44
# 611.05: Add customer to queue 6  Queue length: 44
# 612.08: Add customer to queue 7  Queue length: 44
# 612.38: Add customer to queue 8  Queue length: 44
# 612.71: Add customer to queue 9  Queue length: 44
# 613.22: Add customer to queue 1  Queue length: 45
# 613.97: Add customer to queue 2  Queue length: 45
# 614.61: Add customer to queue 3  Queue length: 45
# 615.56: Add customer to queue 4  Queue length: 45
# 616.43: Add customer to queue 5  Queue length: 45
# 620.84: Add customer to queue 6  Queue length: 45
# 622.15: Add customer to queue 7  Queue length: 45
# 622.89: Add customer to queue 8  Queue length: 45
# 623.55: Add customer to queue 9  Queue length: 45
# 624.02: Add customer to queue 1  Queue length: 46
# 624.08: Add customer to queue 2  Queue length: 46
# 624.10: Add customer to queue 3  Queue length: 46
# 624.39: Add customer to queue 4  Queue length: 46
# 624.63: Add customer to queue 5  Queue length: 46
# 624.64: Add customer to queue 6  Queue length: 46
# 625.95: Add customer to queue 7  Queue length: 46
# 626.40: Add customer to queue 8  Queue length: 46
# 627.85: Add customer to queue 9  Queue length: 46
# 628.18: Add customer to queue 1  Queue length: 47
# 628.95: Add customer to queue 2  Queue length: 47
# 629.37: Add customer to queue 3  Queue length: 47
# 630.12: Add customer to queue 4  Queue length: 47
# 630.13: Add customer to queue 5  Queue length: 47
# 632.88: Add customer to queue 6  Queue length: 47
# 633.06: Add customer to queue 7  Queue length: 47
# 633.34: Add customer to queue 8  Queue length: 47
# 633.91: Add customer to queue 9  Queue length: 47
# 635.39: Add customer to queue 1  Queue length: 48
# 635.63: Add customer to queue 2  Queue length: 48
# 636.46: Add customer to queue 3  Queue length: 48
# 636.71: Add customer to queue 4  Queue length: 48
# 637.56: Add customer to queue 5  Queue length: 48
# 638.56: Add customer to queue 6  Queue length: 48
# 639.72: Add customer to queue 7  Queue length: 48
# 640.86: Add customer to queue 8  Queue length: 48
# 641.33: Add customer to queue 9  Queue length: 48
# 641.69: Add customer to queue 1  Queue length: 49
# 642.06: Add customer to queue 2  Queue length: 49
# 643.06: Add customer to queue 3  Queue length: 49
# 644.40: Add customer to queue 4  Queue length: 49
# 645.18: Add customer to queue 5  Queue length: 49
# 645.41: Add customer to queue 6  Queue length: 49
# 646.67: Add customer to queue 7  Queue length: 49
# 646.82: Add customer to queue 8  Queue length: 49
# 647.80: Add customer to queue 9  Queue length: 49
# 649.62: Add customer to queue 1  Queue length: 50
# 653.81: Add customer to queue 2  Queue length: 50
# 654.02: Add customer to queue 3  Queue length: 50
# 654.36: Add customer to queue 4  Queue length: 50
# 655.75: Add customer to queue 5  Queue length: 50
# 656.45: Add customer to queue 6  Queue length: 50
# 656.87: Add customer to queue 7  Queue length: 50
# 657.28: Add customer to queue 8  Queue length: 50
# 🧍🏾‍♀️ There are [50, 50, 50, 50, 50, 50, 50, 50, 49] people in the queue

# %%
#Theoretical values for a M/G/1 queue

#Average waiting time

#Average service rate
#mu = 3

# Average service time 
#tau = 1/mu

#Variance of service time
#sigma = 1

#Average arrival rate
#l = 1

#utilization
#rho = l*tau

#Average waiting time at equilibrium
#W = (rho*tau/(2*(1-rho))) * (1+ (sigma**2)/(tau**2))

#arrival_distribution = sts.expon(scale=l)
#service_distribution = sts.norm(loc=mu, scale=sigma)
#manager_distribution = sts.norm(loc=5, scale=2**0.5)
cashiers = 3
trial = 1


def comperison_wait_time():
    
    val_mu = np.linspace(0.1, 1, 10)
    #waiting_times_mean = []
    theoretical = []
    empirical = []

    for l in tqdm(val_mu):
        waiting_times = []
        for trial in range(10):
            grocery_store, _ = run_simulation(arrival_distribution= sts.expon(scale=l), service_distribution= sts.norm(loc=3, scale=1), manager_distribution=manager_distribution, queue_count=1, log_events=False)
            for queue in grocery_store.queues:
                waiting_times = waiting_times + queue.waiting_times
            #waiting_times = waiting_times + grocery_store.manager.waiting_times
        empirical.append(np.mean(waiting_times))

        mu = 3
        tau = 1/mu
        sigma = 1
        #l = 1
        rho = l*tau

        W = (rho*tau/(2*(1-rho))) * (1+ (sigma**2)/(tau**2))
        theoretical.append(W)

    plt.plot(val_mu, theoretical, color = 'red', label = r'Theoretical')
    plt.plot(val_mu, empirical, color = 'black', label = r'Simulation results')
    plt.xlabel(r'Arrival rate $\lambda$')
    plt.ylabel(r'Average waiting time (minutes)')
    plt.legend()
    plt.show()


comperison_wait_time()
